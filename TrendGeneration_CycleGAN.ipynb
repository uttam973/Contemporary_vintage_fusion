# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/dataset_.zip' -d '/content/drive/MyDrive'
# Out:
# Archive:  /content/drive/MyDrive/dataset_.zip
#    creating: /content/drive/MyDrive/contemporary_images/
#  extracting: /content/drive/MyDrive/contemporary_images/C47.png
#  extracting: /content/drive/MyDrive/contemporary_images/C48.png
#  extracting: /content/drive/MyDrive/contemporary_images/C49.png
#  extracting: /content/drive/MyDrive/contemporary_images/C50.png
#  extracting: /content/drive/MyDrive/contemporary_images/C51.png
#  extracting: /content/drive/MyDrive/contemporary_images/Copy of 1.jfif
#  extracting: /content/drive/MyDrive/contemporary_images/Copy of 2.jfif
#  extracting: /content/drive/MyDrive/contemporary_images/Copy of 3.jfif
#  extracting: /content/drive/MyDrive/contemporary_images/Copy of 4.jfif
#  extracting: /content/drive/MyDrive/contemporary_images/Copy of 5.jfif
#  extracting: /content/drive/MyDrive/contemporary_images/Copy of 6.jfif
#  extracting: /content/drive/MyDrive/contemporary_images/Copy of 7.jfif
#  extracting: /content/drive/MyDrive/contemporary_images/Copy of 8.jfif
#  extracting: /content/drive/MyDrive/contemporary_images/c1.png
#  extracting: /content/drive/MyDrive/contemporary_images/c10.png
#  extracting: /content/drive/MyDrive/contemporary_images/c100.png
#  extracting: /content/drive/MyDrive/contemporary_images/c101.png
#  extracting: /content/drive/MyDrive/contemporary_images/c102.png
#  extracting: /content/drive/MyDrive/contemporary_images/c103.png
#  extracting: /content/drive/MyDrive/contemporary_images/c104.png
#  extracting: /content/drive/MyDrive/contemporary_images/c105.png
#  extracting: /content/drive/MyDrive/contemporary_images/c106.png
#  extracting: /content/drive/MyDrive/contemporary_images/c107.png
#  extracting: /content/drive/MyDrive/contemporary_images/c108.png
#  extracting: /content/drive/MyDrive/contemporary_images/c109.png
#  extracting: /content/drive/MyDrive/contemporary_images/c11.png
#  extracting: /content/drive/MyDrive/contemporary_images/c110.png
#  extracting: /content/drive/MyDrive/contemporary_images/c111.png
#  extracting: /content/drive/MyDrive/contemporary_images/c112.png
#  extracting: /content/drive/MyDrive/contemporary_images/c113.png
#  extracting: /content/drive/MyDrive/contemporary_images/c114.png
#  extracting: /content/drive/MyDrive/contemporary_images/c12.png
#  extracting: /content/drive/MyDrive/contemporary_images/c13.png
#  extracting: /content/drive/MyDrive/contemporary_images/c14.png
#  extracting: /content/drive/MyDrive/contemporary_images/c15.png
#  extracting: /content/drive/MyDrive/contemporary_images/c16.png
#  extracting: /content/drive/MyDrive/contemporary_images/c17.png
#  extracting: /content/drive/MyDrive/contemporary_images/c18.png
#  extracting: /content/drive/MyDrive/contemporary_images/c19.png
#  extracting: /content/drive/MyDrive/contemporary_images/c2.png
#  extracting: /content/drive/MyDrive/contemporary_images/c20.png
#  extracting: /content/drive/MyDrive/contemporary_images/c21.png
#  extracting: /content/drive/MyDrive/contemporary_images/c22.png
#  extracting: /content/drive/MyDrive/contemporary_images/c23.png
#  extracting: /content/drive/MyDrive/contemporary_images/c24.png
#  extracting: /content/drive/MyDrive/contemporary_images/c25.png
#  extracting: /content/drive/MyDrive/contemporary_images/c26.png
#  extracting: /content/drive/MyDrive/contemporary_images/c27.png
#  extracting: /content/drive/MyDrive/contemporary_images/c28.png
#  extracting: /content/drive/MyDrive/contemporary_images/c29.png
#  extracting: /content/drive/MyDrive/contemporary_images/c3.png
#  extracting: /content/drive/MyDrive/contemporary_images/c30.png
#  extracting: /content/drive/MyDrive/contemporary_images/c31.png
#  extracting: /content/drive/MyDrive/contemporary_images/c32.png
#  extracting: /content/drive/MyDrive/contemporary_images/c33.png
#  extracting: /content/drive/MyDrive/contemporary_images/c34.png
#  extracting: /content/drive/MyDrive/contemporary_images/c35.png
#  extracting: /content/drive/MyDrive/contemporary_images/c36.png
#  extracting: /content/drive/MyDrive/contemporary_images/c37.png
#  extracting: /content/drive/MyDrive/contemporary_images/c38.png
#  extracting: /content/drive/MyDrive/contemporary_images/c39.png
#  extracting: /content/drive/MyDrive/contemporary_images/c4.png
#  extracting: /content/drive/MyDrive/contemporary_images/c40.png
#  extracting: /content/drive/MyDrive/contemporary_images/c41.png
#  extracting: /content/drive/MyDrive/contemporary_images/c42.png
#  extracting: /content/drive/MyDrive/contemporary_images/c43.png
#  extracting: /content/drive/MyDrive/contemporary_images/c44.png
#  extracting: /content/drive/MyDrive/contemporary_images/c45.png
#  extracting: /content/drive/MyDrive/contemporary_images/c46.png
#  extracting: /content/drive/MyDrive/contemporary_images/c5.png
#  extracting: /content/drive/MyDrive/contemporary_images/c52.png
#  extracting: /content/drive/MyDrive/contemporary_images/c53.png
#  extracting: /content/drive/MyDrive/contemporary_images/c54.png
#  extracting: /content/drive/MyDrive/contemporary_images/c55.png
#  extracting: /content/drive/MyDrive/contemporary_images/c56.png
#  extracting: /content/drive/MyDrive/contemporary_images/c57.png
#  extracting: /content/drive/MyDrive/contemporary_images/c58.png
#  extracting: /content/drive/MyDrive/contemporary_images/c59.png
#  extracting: /content/drive/MyDrive/contemporary_images/c6.png
#  extracting: /content/drive/MyDrive/contemporary_images/c60.png
#  extracting: /content/drive/MyDrive/contemporary_images/c61.png
#  extracting: /content/drive/MyDrive/contemporary_images/c62.png
#  extracting: /content/drive/MyDrive/contemporary_images/c63.png
#  extracting: /content/drive/MyDrive/contemporary_images/c64.png
#  extracting: /content/drive/MyDrive/contemporary_images/c65.png
#  extracting: /content/drive/MyDrive/contemporary_images/c66.png
#  extracting: /content/drive/MyDrive/contemporary_images/c67.png
#  extracting: /content/drive/MyDrive/contemporary_images/c68.png
#  extracting: /content/drive/MyDrive/contemporary_images/c69.png
#  extracting: /content/drive/MyDrive/contemporary_images/c7.png
#  extracting: /content/drive/MyDrive/contemporary_images/c70.png
#  extracting: /content/drive/MyDrive/contemporary_images/c71.png
#  extracting: /content/drive/MyDrive/contemporary_images/c72.png
#  extracting: /content/drive/MyDrive/contemporary_images/c73.png
#  extracting: /content/drive/MyDrive/contemporary_images/c74.png
#  extracting: /content/drive/MyDrive/contemporary_images/c75.png
#  extracting: /content/drive/MyDrive/contemporary_images/c76.png
#  extracting: /content/drive/MyDrive/contemporary_images/c77.png
#  extracting: /content/drive/MyDrive/contemporary_images/c78.png
#  extracting: /content/drive/MyDrive/contemporary_images/c79.png
#  extracting: /content/drive/MyDrive/contemporary_images/c8.png
#  extracting: /content/drive/MyDrive/contemporary_images/c80.png
#  extracting: /content/drive/MyDrive/contemporary_images/c81.png
#  extracting: /content/drive/MyDrive/contemporary_images/c82.png
#  extracting: /content/drive/MyDrive/contemporary_images/c83.png
#  extracting: /content/drive/MyDrive/contemporary_images/c84.png
#  extracting: /content/drive/MyDrive/contemporary_images/c85.png
#  extracting: /content/drive/MyDrive/contemporary_images/c86.png
#  extracting: /content/drive/MyDrive/contemporary_images/c87.png
#  extracting: /content/drive/MyDrive/contemporary_images/c88.png
#  extracting: /content/drive/MyDrive/contemporary_images/c89.png
#  extracting: /content/drive/MyDrive/contemporary_images/c9.png
#  extracting: /content/drive/MyDrive/contemporary_images/c90.png
#  extracting: /content/drive/MyDrive/contemporary_images/c91.png
#  extracting: /content/drive/MyDrive/contemporary_images/c92.png
#  extracting: /content/drive/MyDrive/contemporary_images/c93.png
#  extracting: /content/drive/MyDrive/contemporary_images/c94.png
#  extracting: /content/drive/MyDrive/contemporary_images/c95.png
#  extracting: /content/drive/MyDrive/contemporary_images/c96.png
#  extracting: /content/drive/MyDrive/contemporary_images/c97.png
#  extracting: /content/drive/MyDrive/contemporary_images/c98.png
#  extracting: /content/drive/MyDrive/contemporary_images/c99.png
#    creating: /content/drive/MyDrive/vintage_images/
#  extracting: /content/drive/MyDrive/vintage_images/02934a684d2a45d1b83505b56557c52c.jpg
#  extracting: /content/drive/MyDrive/vintage_images/06468eea10ba52c8f36243979e3b9768.jpg
#  extracting: /content/drive/MyDrive/vintage_images/0857549224ec45fc124e0cd15a38b5cb.jpg
#  extracting: /content/drive/MyDrive/vintage_images/0aee8ab82116eb9ace33f42238bf2f2a.jpg
#  extracting: /content/drive/MyDrive/vintage_images/12c7d71ccce5aba5b230a8d98dcef9e1.jpg
#  extracting: /content/drive/MyDrive/vintage_images/1ca2384520ae0be32186b5c4fcebd22a.jpg
#  extracting: /content/drive/MyDrive/vintage_images/292e23c9858bbc3018b19cf4f65d793a.jpg
#  extracting: /content/drive/MyDrive/vintage_images/2999a4da3564cd14e8a1a5fa65276d6c.jpg
#  extracting: /content/drive/MyDrive/vintage_images/2ab6da88775627a81988ddc7a899e8ea.jpg
#  extracting: /content/drive/MyDrive/vintage_images/386167ec2e1e2c9c56f5c7ba9b062c1f.jpg
#  extracting: /content/drive/MyDrive/vintage_images/3bc80638aa37fe8c69a60c66d9c43395.jpg
#  extracting: /content/drive/MyDrive/vintage_images/3e124496fcb41b3fa7d66178b13c24d5.jpg
#  extracting: /content/drive/MyDrive/vintage_images/41713796fe0af2a5a1889d0548044919.jpg
#  extracting: /content/drive/MyDrive/vintage_images/4a19fcb21d387e0c4690ff4c9d6e8352.jpg
#  extracting: /content/drive/MyDrive/vintage_images/60d84ad7e7bbb51cab08e4f945c242cd.jpg
#  extracting: /content/drive/MyDrive/vintage_images/6fbbe04d118d0b9a7441bfdcb19534e6.jpg
#  extracting: /content/drive/MyDrive/vintage_images/7b0dfb5be77727ca339405fc15e08fa2.jpg
#  extracting: /content/drive/MyDrive/vintage_images/80e001622099f9464ff8eb1eea656694.jpg
#  extracting: /content/drive/MyDrive/vintage_images/844fe88535080869fe0555e7f3613cd5.jpg
#  extracting: /content/drive/MyDrive/vintage_images/855d3890038f819c842c156d1276d24b.jpg
#  extracting: /content/drive/MyDrive/vintage_images/85ca56a6eb6757f0d3343f7f805c6f4a.jpg
#  extracting: /content/drive/MyDrive/vintage_images/96d7a0490db6d9fc5da39b529092c25f.jpg
#  extracting: /content/drive/MyDrive/vintage_images/a10cf6452c659d607f21e17eec4ae513.jpg
#  extracting: /content/drive/MyDrive/vintage_images/a62ce5df878efd06267b9b89faf982c4.jpg
#  extracting: /content/drive/MyDrive/vintage_images/ae7fd075df09a8cc43454ac010d702df.jpg
#  extracting: /content/drive/MyDrive/vintage_images/bd5dccb397e5e42af6e617ab24282919.jpg
#  extracting: /content/drive/MyDrive/vintage_images/c637e72084c64858446325d06b723020.jpg
#  extracting: /content/drive/MyDrive/vintage_images/c9987675cd80198086e55999dbeb7307.jpg
#  extracting: /content/drive/MyDrive/vintage_images/d2674987f11053936217058861bfc456.jpg
#  extracting: /content/drive/MyDrive/vintage_images/d49cc521e69e4ae719a7f8c82609b686.jpg
#  extracting: /content/drive/MyDrive/vintage_images/e6bf16ff920133d9549e8f07bebe3033.jpg
#  extracting: /content/drive/MyDrive/vintage_images/ecf96ffc0e02fbd0680cc8f6af7ff798.jpg
#  extracting: /content/drive/MyDrive/vintage_images/f4b444986eda3aacec1658d5760c17c8.jpg
#  extracting: /content/drive/MyDrive/vintage_images/f6d838035faec2c619f3fcaae59ae137.jpg
#  extracting: /content/drive/MyDrive/vintage_images/fc8e024bdbcc24b515784d8731b3f7eb.jpg
#  extracting: /content/drive/MyDrive/vintage_images/v1.png
#  extracting: /content/drive/MyDrive/vintage_images/v10.png
#  extracting: /content/drive/MyDrive/vintage_images/v11.png
#  extracting: /content/drive/MyDrive/vintage_images/v12.png
#  extracting: /content/drive/MyDrive/vintage_images/v13.png
#  extracting: /content/drive/MyDrive/vintage_images/v14.png
#  extracting: /content/drive/MyDrive/vintage_images/v15.png
#  extracting: /content/drive/MyDrive/vintage_images/v16.png
#  extracting: /content/drive/MyDrive/vintage_images/v17.png
#  extracting: /content/drive/MyDrive/vintage_images/v18.png
#  extracting: /content/drive/MyDrive/vintage_images/v19.png
#  extracting: /content/drive/MyDrive/vintage_images/v2.png
#  extracting: /content/drive/MyDrive/vintage_images/v20.png
#  extracting: /content/drive/MyDrive/vintage_images/v21.png
#  extracting: /content/drive/MyDrive/vintage_images/v22.png
#  extracting: /content/drive/MyDrive/vintage_images/v23.png
#  extracting: /content/drive/MyDrive/vintage_images/v24.png
#  extracting: /content/drive/MyDrive/vintage_images/v25.png
#  extracting: /content/drive/MyDrive/vintage_images/v26.png
#  extracting: /content/drive/MyDrive/vintage_images/v27.png
#  extracting: /content/drive/MyDrive/vintage_images/v28.png
#  extracting: /content/drive/MyDrive/vintage_images/v29.png
#  extracting: /content/drive/MyDrive/vintage_images/v3.png
#  extracting: /content/drive/MyDrive/vintage_images/v30.png
#  extracting: /content/drive/MyDrive/vintage_images/v31.png
#  extracting: /content/drive/MyDrive/vintage_images/v32.png
#  extracting: /content/drive/MyDrive/vintage_images/v33.png
#  extracting: /content/drive/MyDrive/vintage_images/v34.png
#  extracting: /content/drive/MyDrive/vintage_images/v35.png
#  extracting: /content/drive/MyDrive/vintage_images/v36.png
#  extracting: /content/drive/MyDrive/vintage_images/v37.png
#  extracting: /content/drive/MyDrive/vintage_images/v38.png
#  extracting: /content/drive/MyDrive/vintage_images/v39.png
#  extracting: /content/drive/MyDrive/vintage_images/v4.png
#  extracting: /content/drive/MyDrive/vintage_images/v40.png
#  extracting: /content/drive/MyDrive/vintage_images/v41.png
#  extracting: /content/drive/MyDrive/vintage_images/v42.png
#  extracting: /content/drive/MyDrive/vintage_images/v43.png
#  extracting: /content/drive/MyDrive/vintage_images/v44.png
#  extracting: /content/drive/MyDrive/vintage_images/v45.png
#  extracting: /content/drive/MyDrive/vintage_images/v46.png
#  extracting: /content/drive/MyDrive/vintage_images/v47.png
#  extracting: /content/drive/MyDrive/vintage_images/v48.png
#  extracting: /content/drive/MyDrive/vintage_images/v49.png
#  extracting: /content/drive/MyDrive/vintage_images/v5.png
#  extracting: /content/drive/MyDrive/vintage_images/v50.png
#  extracting: /content/drive/MyDrive/vintage_images/v51.png
#  extracting: /content/drive/MyDrive/vintage_images/v52.png
#  extracting: /content/drive/MyDrive/vintage_images/v53.png
#  extracting: /content/drive/MyDrive/vintage_images/v54.png
#  extracting: /content/drive/MyDrive/vintage_images/v55.png
#  extracting: /content/drive/MyDrive/vintage_images/v56.png
#  extracting: /content/drive/MyDrive/vintage_images/v57.png
#  extracting: /content/drive/MyDrive/vintage_images/v58.png
#  extracting: /content/drive/MyDrive/vintage_images/v59.png
#  extracting: /content/drive/MyDrive/vintage_images/v6.png
#  extracting: /content/drive/MyDrive/vintage_images/v60.png
#  extracting: /content/drive/MyDrive/vintage_images/v61.png
#  extracting: /content/drive/MyDrive/vintage_images/v62.png
#  extracting: /content/drive/MyDrive/vintage_images/v63.png
#  extracting: /content/drive/MyDrive/vintage_images/v64.png
#  extracting: /content/drive/MyDrive/vintage_images/v65.png
#  extracting: /content/drive/MyDrive/vintage_images/v66.png
#  extracting: /content/drive/MyDrive/vintage_images/v67.png
#  extracting: /content/drive/MyDrive/vintage_images/v68.png
#  extracting: /content/drive/MyDrive/vintage_images/v69.png
#  extracting: /content/drive/MyDrive/vintage_images/v7.png
#  extracting: /content/drive/MyDrive/vintage_images/v70.png
#  extracting: /content/drive/MyDrive/vintage_images/v71.png
#  extracting: /content/drive/MyDrive/vintage_images/v72.png
#  extracting: /content/drive/MyDrive/vintage_images/v73.png
#  extracting: /content/drive/MyDrive/vintage_images/v74.png
#  extracting: /content/drive/MyDrive/vintage_images/v75.png
#  extracting: /content/drive/MyDrive/vintage_images/v76.png
#  extracting: /content/drive/MyDrive/vintage_images/v77.png
#  extracting: /content/drive/MyDrive/vintage_images/v78.png
#  extracting: /content/drive/MyDrive/vintage_images/v79.png
#  extracting: /content/drive/MyDrive/vintage_images/v8.png
#  extracting: /content/drive/MyDrive/vintage_images/v80.png
#  extracting: /content/drive/MyDrive/vintage_images/v81.png
#  extracting: /content/drive/MyDrive/vintage_images/v82.png
#  extracting: /content/drive/MyDrive/vintage_images/v83.png
#  extracting: /content/drive/MyDrive/vintage_images/v84.png
#  extracting: /content/drive/MyDrive/vintage_images/v85.png
#  extracting: /content/drive/MyDrive/vintage_images/v9.png
#  extracting: /content/drive/MyDrive/vintage_images/vintage_coat.jpeg
#  extracting: /content/drive/MyDrive/vintage_images/vintage_gown.jpeg
#  extracting: /content/drive/MyDrive/vintage_images/vintage_saree.jpeg

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.utils as vutils
from torchvision.utils import save_image
from torch.utils.data import DataLoader, Dataset
from PIL import Image
import os
import torchvision.models as models

# ResNet Block
class ResNetBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ResNetBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.in1 = nn.InstanceNorm2d(out_channels, affine=True)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.in2 = nn.InstanceNorm2d(out_channels, affine=True)

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.in1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.in2(out)
        return out + residual

# Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.initial = nn.Conv2d(3, 64, kernel_size=7, padding=3)
        self.initial_in = nn.InstanceNorm2d(64, affine=True)
        self.initial_relu = nn.ReLU(inplace=True)
        self.res_blocks = nn.Sequential(*[ResNetBlock(64, 64) for _ in range(9)])
        self.final = nn.Conv2d(64, 3, kernel_size=7, padding=3)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.initial_relu(self.initial_in(self.initial(x)))
        features = self.res_blocks(x)
        x = self.tanh(self.final(features))
        return x, features

# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(128, affine=True),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(256, affine=True),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1),
            nn.InstanceNorm2d(512, affine=True),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=1)
        )

    def forward(self, x):
        return self.model(x)

# Dataset class
class SingleFolderDataset(Dataset):
    def __init__(self, folder, transform=None):
        self.folder = folder
        self.transform = transform
        self.images = [os.path.join(folder, img) for img in os.listdir(folder) if img.endswith(('png', 'jpg', 'jpeg'))]

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image

# DataLoader function
def load_data(folder, batch_size=1, num_workers=1):
    transform = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor(),
    ])
    dataset = SingleFolderDataset(folder, transform=transform)
    return DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)

# Identity Loss
def identity_loss(real_image, same_image):
    return nn.L1Loss()(real_image, same_image) * 5.0

# Training CycleGAN
def train_cycle_gan(vintage_loader, contemporary_loader, num_epochs=100):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f'Using device: {device}')

    # Initializing models
    Gv2c = Generator().to(device)  # Vintage to Contemporary
    Gc2v = Generator().to(device)  # Contemporary to Vintage
    Dv = Discriminator().to(device)  # Vintage Discriminator
    Dc = Discriminator().to(device)  # Contemporary Discriminator

    # Optimizers
    optimizer_G = optim.Adam(list(Gv2c.parameters()) + list(Gc2v.parameters()), lr=0.0002, betas=(0.5, 0.999))
    optimizer_Dv = optim.Adam(Dv.parameters(), lr=0.0002, betas=(0.5, 0.999))
    optimizer_Dc = optim.Adam(Dc.parameters(), lr=0.0002, betas=(0.5, 0.999))

    criterion_GAN = nn.MSELoss()
    criterion_cycle = nn.L1Loss()

    os.makedirs('output', exist_ok=True)

    for epoch in range(num_epochs):
        for i, (vintage_images, contemporary_images) in enumerate(zip(vintage_loader, contemporary_loader)):
            vintage_images = vintage_images.to(device)
            contemporary_images = contemporary_images.to(device)

            # Training Generators
            optimizer_G.zero_grad()

            # Forward cycle
            fake_contemporary = Gv2c(vintage_images)[0]
            reconstructed_vintage = Gc2v(fake_contemporary)[0]
            cycle_loss_vintage = criterion_cycle(reconstructed_vintage, vintage_images) * 10.0

            # Backward cycle
            fake_vintage = Gc2v(contemporary_images)[0]
            reconstructed_contemporary = Gv2c(fake_vintage)[0]
            cycle_loss_contemporary = criterion_cycle(reconstructed_contemporary, contemporary_images) * 10.0

            identity_loss_vintage = identity_loss(Gv2c(vintage_images)[0], vintage_images)
            identity_loss_contemporary = identity_loss(Gc2v(contemporary_images)[0], contemporary_images)

            # GAN loss
            loss_G = criterion_GAN(Dc(fake_contemporary), torch.ones_like(Dc(fake_contemporary))) + \
                      criterion_GAN(Dv(fake_vintage), torch.ones_like(Dv(fake_vintage))) + \
                      cycle_loss_vintage + cycle_loss_contemporary + \
                      identity_loss_vintage + identity_loss_contemporary

            loss_G.backward()
            optimizer_G.step()

            # Training Discriminators
            optimizer_Dv.zero_grad()
            loss_Dv_real = criterion_GAN(Dv(vintage_images), torch.ones_like(Dv(vintage_images)))
            loss_Dv_fake = criterion_GAN(Dv(fake_vintage.detach()), torch.zeros_like(Dv(fake_vintage.detach())))
            loss_Dv = (loss_Dv_real + loss_Dv_fake) * 0.5
            loss_Dv.backward()
            optimizer_Dv.step()

            optimizer_Dc.zero_grad()
            loss_Dc_real = criterion_GAN(Dc(contemporary_images), torch.ones_like(Dc(contemporary_images)))
            loss_Dc_fake = criterion_GAN(Dc(fake_contemporary.detach()), torch.zeros_like(Dc(fake_contemporary.detach())))
            loss_Dc = (loss_Dc_real + loss_Dc_fake) * 0.5
            loss_Dc.backward()
            optimizer_Dc.step()

            if epoch % 10 == 0:
                vutils.save_image(fake_contemporary, f"/content/drive/MyDrive/output/fake_contemporary_epoch{epoch}_img{i}.png", normalize=True)
                vutils.save_image(fake_vintage, f"/content/drive/MyDrive/output/fake_vintage_epoch{epoch}_img{i}.png", normalize=True)
                print(f'Epoch {epoch}, Loss G: {loss_G.item()}, Loss Dv: {loss_Dv.item()}, Loss Dc: {loss_Dc.item()}')

    torch.save(Gv2c.state_dict(), '/content/drive/MyDrive/output/Gv2c.pth')
    torch.save(Gc2v.state_dict(), '/content/drive/MyDrive/output/Gc2v.pth')

# Loading data
vintage_loader = load_data('/content/drive/MyDrive/vintage_images')
contemporary_loader = load_data('/content/drive/MyDrive/contemporary_images')

train_cycle_gan(vintage_loader, contemporary_loader, num_epochs=100)
# Out:
# Using device: cuda
# Epoch 0, Loss G: 25.128097534179688, Loss Dv: 0.9373265504837036, Loss Dc: 0.6146196126937866
# Epoch 0, Loss G: 23.305248260498047, Loss Dv: 1.1052905321121216, Loss Dc: 1.3422024250030518
# Epoch 0, Loss G: 20.68710708618164, Loss Dv: 0.9475713968276978, Loss Dc: 1.2238121032714844
# Epoch 0, Loss G: 20.008071899414062, Loss Dv: 2.179077625274658, Loss Dc: 1.2332245111465454
# Epoch 0, Loss G: 19.289560317993164, Loss Dv: 0.6205824613571167, Loss Dc: 0.5109186768531799
# Epoch 0, Loss G: 19.42674446105957, Loss Dv: 0.3484826982021332, Loss Dc: 0.35983169078826904
# Epoch 0, Loss G: 18.724390029907227, Loss Dv: 0.2331598848104477, Loss Dc: 0.3775554597377777
# Epoch 0, Loss G: 16.393157958984375, Loss Dv: 0.255127489566803, Loss Dc: 0.2692812383174896
# Epoch 0, Loss G: 16.720617294311523, Loss Dv: 0.2987891137599945, Loss Dc: 0.26400917768478394
# Epoch 0, Loss G: 16.457225799560547, Loss Dv: 0.1501951664686203, Loss Dc: 0.14457310736179352
# Epoch 0, Loss G: 16.16514778137207, Loss Dv: 0.20543800294399261, Loss Dc: 0.26248636841773987
# Epoch 0, Loss G: 17.31070327758789, Loss Dv: 0.18850524723529816, Loss Dc: 0.31156355142593384
# Epoch 0, Loss G: 12.14857292175293, Loss Dv: 0.0917200818657875, Loss Dc: 0.25763797760009766
# Epoch 0, Loss G: 14.116045951843262, Loss Dv: 0.09627526998519897, Loss Dc: 0.2419392168521881
# Epoch 0, Loss G: 12.585923194885254, Loss Dv: 0.11563760787248611, Loss Dc: 0.23758618533611298
# Epoch 0, Loss G: 10.685096740722656, Loss Dv: 0.07111092656850815, Loss Dc: 0.11671704798936844
# Epoch 0, Loss G: 13.14243221282959, Loss Dv: 0.0856436938047409, Loss Dc: 0.14131972193717957
# Epoch 0, Loss G: 15.543659210205078, Loss Dv: 0.3291950225830078, Loss Dc: 0.12486717849969864
# Epoch 0, Loss G: 18.95768165588379, Loss Dv: 0.2786480486392975, Loss Dc: 0.3156113624572754
# Epoch 0, Loss G: 15.48786449432373, Loss Dv: 0.22262616455554962, Loss Dc: 0.14762842655181885
# Epoch 0, Loss G: 14.316451072692871, Loss Dv: 0.224043607711792, Loss Dc: 0.15651172399520874
# Epoch 0, Loss G: 16.407882690429688, Loss Dv: 0.2524915635585785, Loss Dc: 0.4429877996444702
# Epoch 0, Loss G: 13.02492618560791, Loss Dv: 0.18978075683116913, Loss Dc: 0.23725241422653198
# Epoch 0, Loss G: 11.137091636657715, Loss Dv: 0.1931101679801941, Loss Dc: 0.1794281005859375
# Epoch 0, Loss G: 13.151176452636719, Loss Dv: 0.13390269875526428, Loss Dc: 0.14448663592338562
# Epoch 0, Loss G: 13.121763229370117, Loss Dv: 0.2380484640598297, Loss Dc: 0.27860599756240845
# Epoch 0, Loss G: 15.208036422729492, Loss Dv: 0.16053181886672974, Loss Dc: 0.2770330309867859
# Epoch 0, Loss G: 15.907425880432129, Loss Dv: 0.07705067098140717, Loss Dc: 0.26147276163101196
# Epoch 0, Loss G: 11.812830924987793, Loss Dv: 0.11127611994743347, Loss Dc: 0.19906306266784668
# Epoch 0, Loss G: 13.736305236816406, Loss Dv: 0.2711002826690674, Loss Dc: 0.16255603730678558
# Epoch 0, Loss G: 18.588054656982422, Loss Dv: 0.10409162938594818, Loss Dc: 0.21961112320423126
# Epoch 0, Loss G: 18.21455955505371, Loss Dv: 0.0763009786605835, Loss Dc: 0.13743281364440918
# Epoch 0, Loss G: 12.94375228881836, Loss Dv: 0.0695866197347641, Loss Dc: 0.16989071667194366
# Epoch 0, Loss G: 11.724238395690918, Loss Dv: 0.06858082860708237, Loss Dc: 0.11288046836853027
# Epoch 0, Loss G: 15.80324935913086, Loss Dv: 0.22182077169418335, Loss Dc: 0.11580981314182281
# Epoch 0, Loss G: 14.089017868041992, Loss Dv: 0.22746042907238007, Loss Dc: 0.2523903250694275
# Epoch 0, Loss G: 11.306410789489746, Loss Dv: 0.22385677695274353, Loss Dc: 0.1853547841310501
# Epoch 0, Loss G: 13.002830505371094, Loss Dv: 0.21388132870197296, Loss Dc: 0.09295197576284409
# Epoch 0, Loss G: 13.901285171508789, Loss Dv: 0.13210272789001465, Loss Dc: 0.09001615643501282
# Epoch 0, Loss G: 13.556720733642578, Loss Dv: 0.149926096200943, Loss Dc: 0.13418327271938324
# Epoch 0, Loss G: 12.194452285766602, Loss Dv: 0.32971492409706116, Loss Dc: 0.2684171199798584
# Epoch 0, Loss G: 10.90605354309082, Loss Dv: 0.11095491051673889, Loss Dc: 0.15806612372398376
# Epoch 0, Loss G: 14.512099266052246, Loss Dv: 0.4180707633495331, Loss Dc: 0.12360166013240814
# Epoch 0, Loss G: 9.699831008911133, Loss Dv: 0.42000430822372437, Loss Dc: 0.11483119428157806
# Epoch 0, Loss G: 8.234933853149414, Loss Dv: 0.1135537177324295, Loss Dc: 0.08942067623138428
# Epoch 0, Loss G: 13.176907539367676, Loss Dv: 0.15213650465011597, Loss Dc: 0.18752014636993408
# Epoch 0, Loss G: 12.543512344360352, Loss Dv: 0.13689064979553223, Loss Dc: 0.07601939141750336
# Epoch 0, Loss G: 14.376508712768555, Loss Dv: 0.24640586972236633, Loss Dc: 0.27959775924682617
# Epoch 0, Loss G: 10.042174339294434, Loss Dv: 0.23383499681949615, Loss Dc: 0.19747048616409302
# Epoch 0, Loss G: 16.767803192138672, Loss Dv: 0.15682485699653625, Loss Dc: 0.23660027980804443
# Epoch 0, Loss G: 13.588454246520996, Loss Dv: 0.15776492655277252, Loss Dc: 0.14528875052928925
# Epoch 0, Loss G: 14.990558624267578, Loss Dv: 0.20141369104385376, Loss Dc: 0.4634166955947876
# Epoch 0, Loss G: 12.531692504882812, Loss Dv: 0.3028782606124878, Loss Dc: 0.22542239725589752
# Epoch 0, Loss G: 11.306336402893066, Loss Dv: 0.12596124410629272, Loss Dc: 0.21415060758590698
# Epoch 0, Loss G: 13.740224838256836, Loss Dv: 0.17454048991203308, Loss Dc: 0.1586943417787552
# Epoch 0, Loss G: 9.274194717407227, Loss Dv: 0.18293361365795135, Loss Dc: 0.1700403094291687
# Epoch 0, Loss G: 10.845553398132324, Loss Dv: 0.4923728406429291, Loss Dc: 0.16249102354049683
# Epoch 0, Loss G: 12.435907363891602, Loss Dv: 0.18640558421611786, Loss Dc: 0.08903001248836517
# Epoch 0, Loss G: 8.01045036315918, Loss Dv: 0.13069584965705872, Loss Dc: 0.21525311470031738
# Epoch 0, Loss G: 8.424359321594238, Loss Dv: 0.0645153746008873, Loss Dc: 0.2608591318130493
# Epoch 0, Loss G: 9.099549293518066, Loss Dv: 0.08132398128509521, Loss Dc: 0.23884356021881104
# Epoch 0, Loss G: 7.614699840545654, Loss Dv: 0.12894615530967712, Loss Dc: 0.12502218782901764
# Epoch 0, Loss G: 9.681048393249512, Loss Dv: 0.12632796168327332, Loss Dc: 0.29670584201812744
# Epoch 0, Loss G: 12.683082580566406, Loss Dv: 0.32797014713287354, Loss Dc: 0.14785273373126984
# Epoch 0, Loss G: 9.272953033447266, Loss Dv: 0.24576890468597412, Loss Dc: 0.24393388628959656
# Epoch 0, Loss G: 12.703004837036133, Loss Dv: 0.35180923342704773, Loss Dc: 0.2326236069202423
# Epoch 0, Loss G: 12.13641357421875, Loss Dv: 0.1617245227098465, Loss Dc: 0.11252699792385101
# Epoch 0, Loss G: 13.267601013183594, Loss Dv: 0.18496403098106384, Loss Dc: 0.35584700107574463
# Epoch 0, Loss G: 8.790840148925781, Loss Dv: 0.16873370110988617, Loss Dc: 0.2320023626089096
# Epoch 0, Loss G: 11.496792793273926, Loss Dv: 0.12536126375198364, Loss Dc: 0.22998614609241486
# Epoch 0, Loss G: 12.71363353729248, Loss Dv: 0.08563163876533508, Loss Dc: 0.30669140815734863
# Epoch 0, Loss G: 16.165164947509766, Loss Dv: 0.18168905377388, Loss Dc: 0.2359551191329956
# Epoch 0, Loss G: 11.922628402709961, Loss Dv: 0.14203515648841858, Loss Dc: 0.09619411826133728
# Epoch 0, Loss G: 10.91768741607666, Loss Dv: 0.14699354767799377, Loss Dc: 0.3631381690502167
# Epoch 0, Loss G: 13.68973445892334, Loss Dv: 0.1390613466501236, Loss Dc: 0.3025878667831421
# Epoch 0, Loss G: 8.326155662536621, Loss Dv: 0.183162122964859, Loss Dc: 0.14367303252220154
# Epoch 0, Loss G: 9.656760215759277, Loss Dv: 0.5708013772964478, Loss Dc: 0.2648354172706604
# Epoch 0, Loss G: 11.198488235473633, Loss Dv: 0.38577044010162354, Loss Dc: 0.2714652121067047
# Epoch 0, Loss G: 8.022403717041016, Loss Dv: 0.4317680597305298, Loss Dc: 0.12216078490018845
# Epoch 0, Loss G: 12.499419212341309, Loss Dv: 0.33313509821891785, Loss Dc: 0.20804685354232788
# Epoch 0, Loss G: 11.559138298034668, Loss Dv: 0.43656012415885925, Loss Dc: 0.17042404413223267
# Epoch 0, Loss G: 7.702101707458496, Loss Dv: 0.11608287692070007, Loss Dc: 0.19637387990951538
# Epoch 0, Loss G: 11.494458198547363, Loss Dv: 0.10106435418128967, Loss Dc: 0.42491236329078674
# Epoch 0, Loss G: 7.861815929412842, Loss Dv: 0.2604735493659973, Loss Dc: 0.19794631004333496
# Epoch 0, Loss G: 9.314451217651367, Loss Dv: 0.17741674184799194, Loss Dc: 0.21068879961967468
# Epoch 0, Loss G: 7.96798038482666, Loss Dv: 0.068229541182518, Loss Dc: 0.1277102530002594
# Epoch 0, Loss G: 9.766669273376465, Loss Dv: 0.1666753739118576, Loss Dc: 0.19210821390151978
# Epoch 0, Loss G: 9.76537036895752, Loss Dv: 0.2227301001548767, Loss Dc: 0.1385270357131958
# Epoch 0, Loss G: 8.321266174316406, Loss Dv: 0.09046513587236404, Loss Dc: 0.24228063225746155
# Epoch 0, Loss G: 6.061519622802734, Loss Dv: 0.09607481211423874, Loss Dc: 0.20647501945495605
# Epoch 0, Loss G: 10.790563583374023, Loss Dv: 0.14352728426456451, Loss Dc: 0.268592894077301
# Epoch 0, Loss G: 8.305863380432129, Loss Dv: 0.15541236102581024, Loss Dc: 0.09302587807178497
# Epoch 0, Loss G: 10.361465454101562, Loss Dv: 0.3466681241989136, Loss Dc: 0.29445457458496094
# Epoch 0, Loss G: 10.325986862182617, Loss Dv: 0.3399903178215027, Loss Dc: 0.13516362011432648
# Epoch 0, Loss G: 7.5411601066589355, Loss Dv: 0.1133882999420166, Loss Dc: 0.16391831636428833
# Epoch 0, Loss G: 7.814004898071289, Loss Dv: 0.14867094159126282, Loss Dc: 0.17231063544750214
# Epoch 0, Loss G: 10.307026863098145, Loss Dv: 0.329403817653656, Loss Dc: 0.06556905806064606
# Epoch 0, Loss G: 7.131379127502441, Loss Dv: 0.28829556703567505, Loss Dc: 0.25012996792793274
# Epoch 0, Loss G: 7.437061786651611, Loss Dv: 0.3110501170158386, Loss Dc: 0.47550928592681885
# Epoch 0, Loss G: 10.819514274597168, Loss Dv: 0.29231560230255127, Loss Dc: 0.26487797498703003
# Epoch 0, Loss G: 6.4603447914123535, Loss Dv: 0.31190618872642517, Loss Dc: 0.6387068033218384
# Epoch 0, Loss G: 10.396488189697266, Loss Dv: 0.22881700098514557, Loss Dc: 0.36157462000846863
# Epoch 0, Loss G: 7.046682834625244, Loss Dv: 0.16348576545715332, Loss Dc: 0.3660714328289032
# Epoch 0, Loss G: 9.110990524291992, Loss Dv: 0.15722720324993134, Loss Dc: 0.25660470128059387
# Epoch 0, Loss G: 7.819772243499756, Loss Dv: 0.20473039150238037, Loss Dc: 0.24059081077575684
# Epoch 0, Loss G: 7.660074234008789, Loss Dv: 0.11907754838466644, Loss Dc: 0.19442519545555115
# Epoch 0, Loss G: 7.4505157470703125, Loss Dv: 0.08635230362415314, Loss Dc: 0.18619152903556824
# Epoch 0, Loss G: 7.858155250549316, Loss Dv: 0.08636019378900528, Loss Dc: 0.1800851672887802
# Epoch 0, Loss G: 7.37293815612793, Loss Dv: 0.1954110711812973, Loss Dc: 0.12084968388080597
# Epoch 0, Loss G: 6.970512390136719, Loss Dv: 0.21909105777740479, Loss Dc: 0.1539682000875473
# Epoch 0, Loss G: 8.296006202697754, Loss Dv: 0.42365768551826477, Loss Dc: 0.23338352143764496
# Epoch 0, Loss G: 7.875749111175537, Loss Dv: 0.501973569393158, Loss Dc: 0.14240196347236633
# Epoch 0, Loss G: 5.024563312530518, Loss Dv: 0.4621114730834961, Loss Dc: 0.13855254650115967
# Epoch 0, Loss G: 4.989463806152344, Loss Dv: 0.17316412925720215, Loss Dc: 0.1985345333814621
# Epoch 10, Loss G: 4.602850914001465, Loss Dv: 0.22549577057361603, Loss Dc: 0.026550041511654854
# Epoch 10, Loss G: 8.402055740356445, Loss Dv: 0.22299665212631226, Loss Dc: 0.038714248687028885
# Epoch 10, Loss G: 5.276650428771973, Loss Dv: 0.6214045882225037, Loss Dc: 0.049293141812086105
# Epoch 10, Loss G: 6.284542083740234, Loss Dv: 0.07895134389400482, Loss Dc: 0.036710210144519806
# Epoch 10, Loss G: 11.282920837402344, Loss Dv: 0.1697777658700943, Loss Dc: 0.11597933620214462
# Epoch 10, Loss G: 6.414478302001953, Loss Dv: 0.26323774456977844, Loss Dc: 0.02846497669816017
# Epoch 10, Loss G: 5.5947370529174805, Loss Dv: 0.36560770869255066, Loss Dc: 0.048314422369003296
# Epoch 10, Loss G: 4.038071155548096, Loss Dv: 0.19096976518630981, Loss Dc: 0.4981497824192047
# Epoch 10, Loss G: 6.7295122146606445, Loss Dv: 0.10853883624076843, Loss Dc: 0.07612685859203339
# Epoch 10, Loss G: 5.635801792144775, Loss Dv: 0.13478624820709229, Loss Dc: 0.08303198218345642
# Epoch 10, Loss G: 5.124363899230957, Loss Dv: 0.27322065830230713, Loss Dc: 0.15854743123054504
# Epoch 10, Loss G: 4.134008407592773, Loss Dv: 0.1016463190317154, Loss Dc: 0.11109194159507751
# Epoch 10, Loss G: 3.569307327270508, Loss Dv: 0.24254553020000458, Loss Dc: 0.16132217645645142
# Epoch 10, Loss G: 5.911416053771973, Loss Dv: 0.12510323524475098, Loss Dc: 0.34668612480163574
# Epoch 10, Loss G: 5.8567705154418945, Loss Dv: 0.30563411116600037, Loss Dc: 0.2554279565811157
# Epoch 10, Loss G: 3.6461422443389893, Loss Dv: 0.09767460823059082, Loss Dc: 0.11259066313505173
# Epoch 10, Loss G: 5.616070747375488, Loss Dv: 0.353660523891449, Loss Dc: 0.1018262654542923
# Epoch 10, Loss G: 7.945780277252197, Loss Dv: 0.06489034742116928, Loss Dc: 0.03249971196055412
# Epoch 10, Loss G: 6.239080905914307, Loss Dv: 0.40905919671058655, Loss Dc: 0.12679892778396606
# Epoch 10, Loss G: 5.601955413818359, Loss Dv: 0.09593937546014786, Loss Dc: 0.15451136231422424
# Epoch 10, Loss G: 4.179653644561768, Loss Dv: 0.20583724975585938, Loss Dc: 0.08555080741643906
# Epoch 10, Loss G: 4.697129249572754, Loss Dv: 0.09275791049003601, Loss Dc: 0.2740726172924042
# Epoch 10, Loss G: 6.880385398864746, Loss Dv: 0.11681914329528809, Loss Dc: 0.12253760546445847
# Epoch 10, Loss G: 5.371031761169434, Loss Dv: 0.06395570933818817, Loss Dc: 0.10531077533960342
# Epoch 10, Loss G: 6.787195205688477, Loss Dv: 0.031030181795358658, Loss Dc: 0.036293912678956985
# Epoch 10, Loss G: 5.592854976654053, Loss Dv: 0.1943749338388443, Loss Dc: 0.24461272358894348
# Epoch 10, Loss G: 4.324763298034668, Loss Dv: 0.276313453912735, Loss Dc: 0.33123159408569336
# Epoch 10, Loss G: 5.871023178100586, Loss Dv: 0.22777506709098816, Loss Dc: 0.03906248137354851
# Epoch 10, Loss G: 4.025540828704834, Loss Dv: 0.28059929609298706, Loss Dc: 0.4417147934436798
# Epoch 10, Loss G: 3.3247804641723633, Loss Dv: 0.27179059386253357, Loss Dc: 0.12174199521541595
# Epoch 10, Loss G: 5.037353992462158, Loss Dv: 0.11647902429103851, Loss Dc: 0.20748043060302734
# Epoch 10, Loss G: 3.5729734897613525, Loss Dv: 0.16701926290988922, Loss Dc: 0.3677026331424713
# Epoch 10, Loss G: 4.315881729125977, Loss Dv: 0.12212634831666946, Loss Dc: 0.36379605531692505
# Epoch 10, Loss G: 4.038887023925781, Loss Dv: 0.09287077188491821, Loss Dc: 0.16915376484394073
# Epoch 10, Loss G: 8.45965576171875, Loss Dv: 0.051077622920274734, Loss Dc: 0.24634766578674316
# Epoch 10, Loss G: 8.624850273132324, Loss Dv: 0.1654224395751953, Loss Dc: 0.08082040399312973
# Epoch 10, Loss G: 9.030790328979492, Loss Dv: 0.3609672784805298, Loss Dc: 0.06226425990462303
# Epoch 10, Loss G: 6.658398151397705, Loss Dv: 0.028970373794436455, Loss Dc: 0.36623483896255493
# Epoch 10, Loss G: 5.536959648132324, Loss Dv: 0.10991998016834259, Loss Dc: 0.05704015865921974
# Epoch 10, Loss G: 6.09107780456543, Loss Dv: 0.06792454421520233, Loss Dc: 0.08723652362823486
# Epoch 10, Loss G: 6.701416015625, Loss Dv: 0.1032872349023819, Loss Dc: 0.1473231315612793
# Epoch 10, Loss G: 6.4178667068481445, Loss Dv: 0.07918450981378555, Loss Dc: 0.07721593976020813
# Epoch 10, Loss G: 5.990870475769043, Loss Dv: 0.11372244358062744, Loss Dc: 0.12078604847192764
# Epoch 10, Loss G: 8.351677894592285, Loss Dv: 0.2583690881729126, Loss Dc: 0.11288848519325256
# Epoch 10, Loss G: 4.445707321166992, Loss Dv: 0.02514636144042015, Loss Dc: 0.12195219099521637
# Epoch 10, Loss G: 5.279371738433838, Loss Dv: 0.1333267241716385, Loss Dc: 0.06674271076917648
# Epoch 10, Loss G: 5.299171447753906, Loss Dv: 0.20846419036388397, Loss Dc: 0.08080372214317322
# Epoch 10, Loss G: 6.228233337402344, Loss Dv: 0.06444121897220612, Loss Dc: 0.08058041334152222
# Epoch 10, Loss G: 4.625273704528809, Loss Dv: 0.31339550018310547, Loss Dc: 0.06304841488599777
# Epoch 10, Loss G: 6.857893943786621, Loss Dv: 0.043188538402318954, Loss Dc: 0.02104286476969719
# Epoch 10, Loss G: 5.21695613861084, Loss Dv: 0.25565746426582336, Loss Dc: 0.07166446000337601
# Epoch 10, Loss G: 7.082693099975586, Loss Dv: 0.20799309015274048, Loss Dc: 0.03791690617799759
# Epoch 10, Loss G: 8.058680534362793, Loss Dv: 0.023506425321102142, Loss Dc: 0.08943282067775726
# Epoch 10, Loss G: 3.2431578636169434, Loss Dv: 0.43039435148239136, Loss Dc: 0.20496170222759247
# Epoch 10, Loss G: 5.8370537757873535, Loss Dv: 0.24688804149627686, Loss Dc: 0.024043772369623184
# Epoch 10, Loss G: 9.956998825073242, Loss Dv: 0.21101495623588562, Loss Dc: 0.12985004484653473
# Epoch 10, Loss G: 5.963523864746094, Loss Dv: 0.28496092557907104, Loss Dc: 0.025044018402695656
# Epoch 10, Loss G: 5.376600742340088, Loss Dv: 0.06249716132879257, Loss Dc: 0.054989587515592575
# Epoch 10, Loss G: 6.168493747711182, Loss Dv: 0.10547861456871033, Loss Dc: 0.11079807579517365
# Epoch 10, Loss G: 9.303089141845703, Loss Dv: 0.07139170914888382, Loss Dc: 0.03645046800374985
# Epoch 10, Loss G: 6.724416732788086, Loss Dv: 0.04611346125602722, Loss Dc: 0.013763274066150188
# Epoch 10, Loss G: 4.322452545166016, Loss Dv: 0.19396834075450897, Loss Dc: 0.3228641748428345
# Epoch 10, Loss G: 4.950300216674805, Loss Dv: 0.1217251569032669, Loss Dc: 0.08314919471740723
# Epoch 10, Loss G: 6.352616310119629, Loss Dv: 0.06340503692626953, Loss Dc: 0.23509345948696136
# Epoch 10, Loss G: 5.480465888977051, Loss Dv: 0.2895900309085846, Loss Dc: 0.3803647458553314
# Epoch 10, Loss G: 3.395312786102295, Loss Dv: 0.11192487925291061, Loss Dc: 0.1940511167049408
# Epoch 10, Loss G: 6.934330463409424, Loss Dv: 0.13321731984615326, Loss Dc: 0.014755561016499996
# Epoch 10, Loss G: 6.881381988525391, Loss Dv: 0.11696076393127441, Loss Dc: 0.056777473539114
# Epoch 10, Loss G: 4.390356063842773, Loss Dv: 0.27332639694213867, Loss Dc: 0.04511890560388565
# Epoch 10, Loss G: 4.392467498779297, Loss Dv: 0.20667067170143127, Loss Dc: 0.053804364055395126
# Epoch 10, Loss G: 4.506146430969238, Loss Dv: 0.27225053310394287, Loss Dc: 0.07397007942199707
# Epoch 10, Loss G: 5.700162887573242, Loss Dv: 0.06981858611106873, Loss Dc: 0.06497103720903397
# Epoch 10, Loss G: 5.35122537612915, Loss Dv: 0.26430466771125793, Loss Dc: 0.011814095079898834
# Epoch 10, Loss G: 4.754363059997559, Loss Dv: 0.12274178117513657, Loss Dc: 0.08365170657634735
# Epoch 10, Loss G: 4.2354736328125, Loss Dv: 0.09129463881254196, Loss Dc: 0.1898699402809143
# Epoch 10, Loss G: 3.454512119293213, Loss Dv: 0.33186694979667664, Loss Dc: 0.19543367624282837
# Epoch 10, Loss G: 5.528205871582031, Loss Dv: 0.08743308484554291, Loss Dc: 0.040406160056591034
# Epoch 10, Loss G: 5.316338062286377, Loss Dv: 0.3570241332054138, Loss Dc: 0.11540204286575317
# Epoch 10, Loss G: 4.019076824188232, Loss Dv: 0.2844998836517334, Loss Dc: 0.7656728625297546
# Epoch 10, Loss G: 3.76116943359375, Loss Dv: 0.12617498636245728, Loss Dc: 0.37593865394592285
# Epoch 10, Loss G: 6.270908355712891, Loss Dv: 0.11867603659629822, Loss Dc: 0.1199067011475563
# Epoch 10, Loss G: 5.47565221786499, Loss Dv: 0.13768494129180908, Loss Dc: 0.27261030673980713
# Epoch 10, Loss G: 5.586598873138428, Loss Dv: 0.15046101808547974, Loss Dc: 0.3003169298171997
# Epoch 10, Loss G: 6.621059894561768, Loss Dv: 0.13042116165161133, Loss Dc: 0.23046420514583588
# Epoch 10, Loss G: 5.473287105560303, Loss Dv: 0.21204012632369995, Loss Dc: 0.19787922501564026
# Epoch 10, Loss G: 2.7285428047180176, Loss Dv: 0.132644385099411, Loss Dc: 0.3899920582771301
# Epoch 10, Loss G: 6.367356777191162, Loss Dv: 0.04865957424044609, Loss Dc: 0.2704630196094513
# Epoch 10, Loss G: 6.111614227294922, Loss Dv: 0.16901974380016327, Loss Dc: 0.21689946949481964
# Epoch 10, Loss G: 5.208732604980469, Loss Dv: 0.11136483401060104, Loss Dc: 0.2194693237543106
# Epoch 10, Loss G: 4.459601402282715, Loss Dv: 0.1706337183713913, Loss Dc: 0.06351960450410843
# Epoch 10, Loss G: 4.092787742614746, Loss Dv: 0.26439571380615234, Loss Dc: 0.17857526242733002
# Epoch 10, Loss G: 6.904179573059082, Loss Dv: 0.159438356757164, Loss Dc: 0.11176937818527222
# Epoch 10, Loss G: 5.176198959350586, Loss Dv: 0.4539961516857147, Loss Dc: 0.08970606327056885
# Epoch 10, Loss G: 5.305851459503174, Loss Dv: 0.28488755226135254, Loss Dc: 0.3122883439064026
# Epoch 10, Loss G: 4.012452602386475, Loss Dv: 0.1438024342060089, Loss Dc: 0.26028764247894287
# Epoch 10, Loss G: 4.061621189117432, Loss Dv: 0.13734939694404602, Loss Dc: 0.18795061111450195
# Epoch 10, Loss G: 6.383899688720703, Loss Dv: 0.17790308594703674, Loss Dc: 0.08021117746829987
# Epoch 10, Loss G: 9.346640586853027, Loss Dv: 0.13611532747745514, Loss Dc: 0.19257423281669617
# Epoch 10, Loss G: 3.6723804473876953, Loss Dv: 0.19334298372268677, Loss Dc: 0.19198772311210632
# Epoch 10, Loss G: 3.548654556274414, Loss Dv: 0.18753668665885925, Loss Dc: 0.05256710946559906
# Epoch 10, Loss G: 3.031374931335449, Loss Dv: 0.3888031244277954, Loss Dc: 0.38588273525238037
# Epoch 10, Loss G: 4.109276294708252, Loss Dv: 0.1433534026145935, Loss Dc: 0.11757302284240723
# Epoch 10, Loss G: 5.353797912597656, Loss Dv: 0.1658211052417755, Loss Dc: 0.19058434665203094
# Epoch 10, Loss G: 6.762555122375488, Loss Dv: 0.24165979027748108, Loss Dc: 0.07532002776861191
# Epoch 10, Loss G: 3.7528269290924072, Loss Dv: 0.16575981676578522, Loss Dc: 0.08468788117170334
# Epoch 10, Loss G: 4.062623023986816, Loss Dv: 0.15695837140083313, Loss Dc: 0.1966899037361145
# Epoch 10, Loss G: 4.795243263244629, Loss Dv: 0.13771823048591614, Loss Dc: 0.15448865294456482
# Epoch 10, Loss G: 3.7533373832702637, Loss Dv: 0.3356516361236572, Loss Dc: 0.23953862488269806
# Epoch 10, Loss G: 3.469089984893799, Loss Dv: 0.14662429690361023, Loss Dc: 0.2286977916955948
# Epoch 10, Loss G: 5.476673603057861, Loss Dv: 0.06264906376600266, Loss Dc: 0.20012658834457397
# Epoch 10, Loss G: 4.39790678024292, Loss Dv: 0.39155086874961853, Loss Dc: 0.2254367619752884
# Epoch 10, Loss G: 2.674143075942993, Loss Dv: 0.3476748466491699, Loss Dc: 0.2318992167711258
# Epoch 10, Loss G: 3.239985942840576, Loss Dv: 0.21337425708770752, Loss Dc: 0.20495565235614777
# Epoch 10, Loss G: 4.1834397315979, Loss Dv: 0.22309008240699768, Loss Dc: 0.1104617640376091
# Epoch 20, Loss G: 4.470276832580566, Loss Dv: 0.08758608996868134, Loss Dc: 0.10290450602769852
# Epoch 20, Loss G: 7.130987167358398, Loss Dv: 0.47213396430015564, Loss Dc: 0.08080193400382996
# Epoch 20, Loss G: 6.261673927307129, Loss Dv: 0.051172442734241486, Loss Dc: 0.026746293529868126
# Epoch 20, Loss G: 5.945940971374512, Loss Dv: 0.11883453279733658, Loss Dc: 0.023285221308469772
# Epoch 20, Loss G: 5.423704147338867, Loss Dv: 0.12688279151916504, Loss Dc: 0.08852358162403107
# Epoch 20, Loss G: 3.966033458709717, Loss Dv: 0.19856102764606476, Loss Dc: 0.060243409126996994
# Epoch 20, Loss G: 3.766594171524048, Loss Dv: 0.1185908168554306, Loss Dc: 0.050712063908576965
# Epoch 20, Loss G: 5.389068603515625, Loss Dv: 0.06220198795199394, Loss Dc: 0.07302521914243698
# Epoch 20, Loss G: 4.824428558349609, Loss Dv: 0.024819660931825638, Loss Dc: 0.44353392720222473
# Epoch 20, Loss G: 4.369025230407715, Loss Dv: 0.09765708446502686, Loss Dc: 0.4355635643005371
# Epoch 20, Loss G: 4.475030899047852, Loss Dv: 0.1772359311580658, Loss Dc: 0.09311257302761078
# Epoch 20, Loss G: 5.616184711456299, Loss Dv: 0.014974216930568218, Loss Dc: 0.0614868700504303
# Epoch 20, Loss G: 5.254462718963623, Loss Dv: 0.05784641578793526, Loss Dc: 0.047437071800231934
# Epoch 20, Loss G: 6.087093353271484, Loss Dv: 0.049092888832092285, Loss Dc: 0.0880284532904625
# Epoch 20, Loss G: 4.843677997589111, Loss Dv: 0.07919003069400787, Loss Dc: 0.048930101096630096
# Epoch 20, Loss G: 5.744357585906982, Loss Dv: 0.08444324880838394, Loss Dc: 0.039850860834121704
# Epoch 20, Loss G: 5.69198751449585, Loss Dv: 0.04818542301654816, Loss Dc: 0.07562659680843353
# Epoch 20, Loss G: 4.748982906341553, Loss Dv: 0.1731451153755188, Loss Dc: 0.06536398082971573
# Epoch 20, Loss G: 4.279054641723633, Loss Dv: 0.10308536887168884, Loss Dc: 0.169742614030838
# Epoch 20, Loss G: 4.441091537475586, Loss Dv: 0.037127021700143814, Loss Dc: 0.0890742763876915
# Epoch 20, Loss G: 5.730545997619629, Loss Dv: 0.034989044070243835, Loss Dc: 0.03933708369731903
# Epoch 20, Loss G: 6.020646572113037, Loss Dv: 0.01886487752199173, Loss Dc: 0.038017984479665756
# Epoch 20, Loss G: 6.006442070007324, Loss Dv: 0.0405004620552063, Loss Dc: 0.18577086925506592
# Epoch 20, Loss G: 3.721055507659912, Loss Dv: 0.18427501618862152, Loss Dc: 0.18749898672103882
# Epoch 20, Loss G: 3.9646878242492676, Loss Dv: 0.08472812175750732, Loss Dc: 0.1047404557466507
# Epoch 20, Loss G: 7.423993110656738, Loss Dv: 0.21670721471309662, Loss Dc: 0.09037802368402481
# Epoch 20, Loss G: 6.143557548522949, Loss Dv: 0.07337988913059235, Loss Dc: 0.09220748394727707
# Epoch 20, Loss G: 7.406745433807373, Loss Dv: 0.12130601704120636, Loss Dc: 0.372962087392807
# Epoch 20, Loss G: 3.315504550933838, Loss Dv: 0.10873838514089584, Loss Dc: 0.09508451074361801
# Epoch 20, Loss G: 5.021690845489502, Loss Dv: 0.05343702435493469, Loss Dc: 0.10509029030799866
# Epoch 20, Loss G: 3.7635598182678223, Loss Dv: 0.23724596202373505, Loss Dc: 0.09846307337284088
# Epoch 20, Loss G: 2.9569625854492188, Loss Dv: 0.12097564339637756, Loss Dc: 0.1366444081068039
# Epoch 20, Loss G: 6.033010482788086, Loss Dv: 0.10533914715051651, Loss Dc: 0.10527392476797104
# Epoch 20, Loss G: 7.264853000640869, Loss Dv: 0.17597562074661255, Loss Dc: 0.03516817092895508
# Epoch 20, Loss G: 5.07016134262085, Loss Dv: 0.12228042632341385, Loss Dc: 0.04890996962785721
# Epoch 20, Loss G: 3.3209710121154785, Loss Dv: 0.07292332500219345, Loss Dc: 0.08105984330177307
# Epoch 20, Loss G: 5.206684589385986, Loss Dv: 0.0954747200012207, Loss Dc: 0.06756559759378433
# Epoch 20, Loss G: 7.130680084228516, Loss Dv: 0.13411040604114532, Loss Dc: 0.02689535729587078
# Epoch 20, Loss G: 5.111188888549805, Loss Dv: 0.08872447162866592, Loss Dc: 0.0598750039935112
# Epoch 20, Loss G: 3.7934670448303223, Loss Dv: 0.04045511782169342, Loss Dc: 0.06617306172847748
# Epoch 20, Loss G: 3.9621691703796387, Loss Dv: 0.039733611047267914, Loss Dc: 0.08009518682956696
# Epoch 20, Loss G: 3.570537567138672, Loss Dv: 0.16483068466186523, Loss Dc: 0.055283501744270325
# Epoch 20, Loss G: 5.442961692810059, Loss Dv: 0.18346011638641357, Loss Dc: 0.16600631177425385
# Epoch 20, Loss G: 4.528537750244141, Loss Dv: 0.1738336682319641, Loss Dc: 0.01210520975291729
# Epoch 20, Loss G: 3.722348213195801, Loss Dv: 0.17520898580551147, Loss Dc: 0.17934538424015045
# Epoch 20, Loss G: 8.198452949523926, Loss Dv: 0.024846941232681274, Loss Dc: 0.013090649619698524
# Epoch 20, Loss G: 4.91434383392334, Loss Dv: 0.12702986598014832, Loss Dc: 0.0137222521007061
# Epoch 20, Loss G: 4.2282609939575195, Loss Dv: 0.2324012815952301, Loss Dc: 0.37578245997428894
# Epoch 20, Loss G: 4.41960334777832, Loss Dv: 0.034276749938726425, Loss Dc: 0.07735948264598846
# Epoch 20, Loss G: 4.653133392333984, Loss Dv: 0.036647044122219086, Loss Dc: 0.07412799447774887
# Epoch 20, Loss G: 3.6954853534698486, Loss Dv: 0.08614472299814224, Loss Dc: 0.08749064058065414
# Epoch 20, Loss G: 3.8809547424316406, Loss Dv: 0.2506680488586426, Loss Dc: 0.2588406205177307
# Epoch 20, Loss G: 2.992155075073242, Loss Dv: 0.1610410362482071, Loss Dc: 0.1896040439605713
# Epoch 20, Loss G: 5.234140872955322, Loss Dv: 0.16229405999183655, Loss Dc: 0.11607909947633743
# Epoch 20, Loss G: 5.088531970977783, Loss Dv: 0.16245174407958984, Loss Dc: 0.048102810978889465
# Epoch 20, Loss G: 4.217236518859863, Loss Dv: 0.2042093724012375, Loss Dc: 0.2577701210975647
# Epoch 20, Loss G: 4.542718887329102, Loss Dv: 0.19731229543685913, Loss Dc: 0.07961233705282211
# Epoch 20, Loss G: 2.912818431854248, Loss Dv: 0.22019843757152557, Loss Dc: 0.21016663312911987
# Epoch 20, Loss G: 4.756603717803955, Loss Dv: 0.33064237236976624, Loss Dc: 0.3327762186527252
# Epoch 20, Loss G: 4.273221015930176, Loss Dv: 0.19392386078834534, Loss Dc: 0.17187784612178802
# Epoch 20, Loss G: 5.454615592956543, Loss Dv: 0.07158289849758148, Loss Dc: 0.0674315094947815
# Epoch 20, Loss G: 4.079752445220947, Loss Dv: 0.2363646924495697, Loss Dc: 0.055708643049001694
# Epoch 20, Loss G: 3.6540422439575195, Loss Dv: 0.40722334384918213, Loss Dc: 0.06955419480800629
# Epoch 20, Loss G: 4.736896991729736, Loss Dv: 0.22436781227588654, Loss Dc: 0.1117919310927391
# Epoch 20, Loss G: 4.167492389678955, Loss Dv: 0.15168575942516327, Loss Dc: 0.18778730928897858
# Epoch 20, Loss G: 7.2856669425964355, Loss Dv: 0.15311212837696075, Loss Dc: 0.06258877366781235
# Epoch 20, Loss G: 3.955780267715454, Loss Dv: 0.29493358731269836, Loss Dc: 0.1659320592880249
# Epoch 20, Loss G: 3.4837403297424316, Loss Dv: 0.14268243312835693, Loss Dc: 0.23886363208293915
# Epoch 20, Loss G: 5.860855579376221, Loss Dv: 0.07210853695869446, Loss Dc: 0.11122968047857285
# Epoch 20, Loss G: 6.547788619995117, Loss Dv: 0.11256726831197739, Loss Dc: 0.013305388391017914
# Epoch 20, Loss G: 4.352595329284668, Loss Dv: 0.08959083259105682, Loss Dc: 0.12343664467334747
# Epoch 20, Loss G: 6.736203193664551, Loss Dv: 0.22569797933101654, Loss Dc: 0.07954101264476776
# Epoch 20, Loss G: 7.050363063812256, Loss Dv: 0.35216987133026123, Loss Dc: 0.1143312081694603
# Epoch 20, Loss G: 2.7250101566314697, Loss Dv: 0.20761168003082275, Loss Dc: 0.20151768624782562
# Epoch 20, Loss G: 7.780218124389648, Loss Dv: 0.16664737462997437, Loss Dc: 0.08153142780065536
# Epoch 20, Loss G: 3.1331069469451904, Loss Dv: 0.2733950912952423, Loss Dc: 0.26999929547309875
# Epoch 20, Loss G: 4.469216346740723, Loss Dv: 0.10848551988601685, Loss Dc: 0.02779892459511757
# Epoch 20, Loss G: 4.826361656188965, Loss Dv: 0.0245598666369915, Loss Dc: 0.1318160891532898
# Epoch 20, Loss G: 4.3967132568359375, Loss Dv: 0.07116267085075378, Loss Dc: 0.15281294286251068
# Epoch 20, Loss G: 4.548730373382568, Loss Dv: 0.11451231688261032, Loss Dc: 0.23816508054733276
# Epoch 20, Loss G: 3.368622064590454, Loss Dv: 0.039606496691703796, Loss Dc: 0.124993696808815
# Epoch 20, Loss G: 3.438882350921631, Loss Dv: 0.33638110756874084, Loss Dc: 0.44956475496292114
# Epoch 20, Loss G: 4.150225639343262, Loss Dv: 0.22578585147857666, Loss Dc: 0.06021968647837639
# Epoch 20, Loss G: 4.673093318939209, Loss Dv: 0.1328296661376953, Loss Dc: 0.10894016176462173
# Epoch 20, Loss G: 3.9470701217651367, Loss Dv: 0.11775493621826172, Loss Dc: 0.38673484325408936
# Epoch 20, Loss G: 3.9994537830352783, Loss Dv: 0.08607325702905655, Loss Dc: 0.121602863073349
# Epoch 20, Loss G: 3.4384641647338867, Loss Dv: 0.14537480473518372, Loss Dc: 0.31012290716171265
# Epoch 20, Loss G: 3.442270278930664, Loss Dv: 0.09927257150411606, Loss Dc: 0.13508212566375732
# Epoch 20, Loss G: 5.091686248779297, Loss Dv: 0.05448754131793976, Loss Dc: 0.16570603847503662
# Epoch 20, Loss G: 3.583667516708374, Loss Dv: 0.19771502912044525, Loss Dc: 0.04917343333363533
# Epoch 20, Loss G: 4.276191711425781, Loss Dv: 0.06758566200733185, Loss Dc: 0.040667880326509476
# Epoch 20, Loss G: 5.651141166687012, Loss Dv: 0.032773539423942566, Loss Dc: 0.011056751012802124
# Epoch 20, Loss G: 6.577877998352051, Loss Dv: 0.014225024729967117, Loss Dc: 0.03323694318532944
# Epoch 20, Loss G: 4.264894485473633, Loss Dv: 0.08171094954013824, Loss Dc: 0.011823520995676517
# Epoch 20, Loss G: 5.1052727699279785, Loss Dv: 0.027911683544516563, Loss Dc: 0.02690328098833561
# Epoch 20, Loss G: 7.629022598266602, Loss Dv: 0.07027795165777206, Loss Dc: 0.02968657575547695
# Epoch 20, Loss G: 4.457952976226807, Loss Dv: 0.058492135256528854, Loss Dc: 0.04753417894244194
# Epoch 20, Loss G: 4.071691036224365, Loss Dv: 0.017661679536104202, Loss Dc: 0.12268121540546417
# Epoch 20, Loss G: 6.8685832023620605, Loss Dv: 0.2132853865623474, Loss Dc: 0.02983354777097702
# Epoch 20, Loss G: 3.2250006198883057, Loss Dv: 0.21982234716415405, Loss Dc: 0.13922421634197235
# Epoch 20, Loss G: 4.775515556335449, Loss Dv: 0.2004779428243637, Loss Dc: 0.009686070494353771
# Epoch 20, Loss G: 4.596916675567627, Loss Dv: 0.01719176396727562, Loss Dc: 0.18306420743465424
# Epoch 20, Loss G: 5.431432247161865, Loss Dv: 0.0301080159842968, Loss Dc: 0.026119574904441833
# Epoch 20, Loss G: 5.967928886413574, Loss Dv: 0.0490279383957386, Loss Dc: 0.030596375465393066
# Epoch 20, Loss G: 5.382408142089844, Loss Dv: 0.039445627480745316, Loss Dc: 0.02619146928191185
# Epoch 20, Loss G: 7.6604509353637695, Loss Dv: 0.07107605785131454, Loss Dc: 0.019308730959892273
# Epoch 20, Loss G: 4.37372350692749, Loss Dv: 0.1309182196855545, Loss Dc: 0.036331020295619965
# Epoch 20, Loss G: 4.4844441413879395, Loss Dv: 0.0525154285132885, Loss Dc: 0.028957895934581757
# Epoch 20, Loss G: 4.6155219078063965, Loss Dv: 0.18194015324115753, Loss Dc: 0.04315850883722305
# Epoch 20, Loss G: 4.997585773468018, Loss Dv: 0.08027075976133347, Loss Dc: 0.02625465765595436
# Epoch 20, Loss G: 5.764466285705566, Loss Dv: 0.02066488191485405, Loss Dc: 0.037373948842287064
# Epoch 20, Loss G: 5.1931071281433105, Loss Dv: 0.16956321895122528, Loss Dc: 0.18265247344970703
# Epoch 20, Loss G: 4.870939254760742, Loss Dv: 0.2750169038772583, Loss Dc: 0.038430310785770416
# Epoch 20, Loss G: 4.703227996826172, Loss Dv: 0.241904616355896, Loss Dc: 0.32138264179229736
# Epoch 30, Loss G: 5.715691089630127, Loss Dv: 0.023994337767362595, Loss Dc: 0.12514223158359528
# Epoch 30, Loss G: 6.304635524749756, Loss Dv: 0.1804603487253189, Loss Dc: 0.037422992289066315
# Epoch 30, Loss G: 7.152737617492676, Loss Dv: 0.08429713547229767, Loss Dc: 0.06662352383136749
# Epoch 30, Loss G: 4.702510356903076, Loss Dv: 0.06822774559259415, Loss Dc: 0.011756233870983124
# Epoch 30, Loss G: 3.240208387374878, Loss Dv: 0.20277085900306702, Loss Dc: 0.034880563616752625
# Epoch 30, Loss G: 5.937456130981445, Loss Dv: 0.029642213135957718, Loss Dc: 0.023712370544672012
# Epoch 30, Loss G: 4.087022304534912, Loss Dv: 0.1357187032699585, Loss Dc: 0.04457536339759827
# Epoch 30, Loss G: 3.4472317695617676, Loss Dv: 0.07807125151157379, Loss Dc: 0.1819302886724472
# Epoch 30, Loss G: 5.541364669799805, Loss Dv: 0.011601293459534645, Loss Dc: 0.036954350769519806
# Epoch 30, Loss G: 4.078921794891357, Loss Dv: 0.21912305057048798, Loss Dc: 0.11251833289861679
# Epoch 30, Loss G: 2.847926378250122, Loss Dv: 0.12765049934387207, Loss Dc: 0.07698309421539307
# Epoch 30, Loss G: 4.4410295486450195, Loss Dv: 0.2029648870229721, Loss Dc: 0.025340605527162552
# Epoch 30, Loss G: 5.116401195526123, Loss Dv: 0.04422245919704437, Loss Dc: 0.013070797547698021
# Epoch 30, Loss G: 3.2443320751190186, Loss Dv: 0.08215595036745071, Loss Dc: 0.07767163217067719
# Epoch 30, Loss G: 4.738409996032715, Loss Dv: 0.2529009282588959, Loss Dc: 0.04130343347787857
# Epoch 30, Loss G: 4.682527542114258, Loss Dv: 0.0770169198513031, Loss Dc: 0.19243784248828888
# Epoch 30, Loss G: 2.9591052532196045, Loss Dv: 0.1542876958847046, Loss Dc: 0.0923919528722763
# Epoch 30, Loss G: 4.00785493850708, Loss Dv: 0.059459663927555084, Loss Dc: 0.08958965539932251
# Epoch 30, Loss G: 4.8415751457214355, Loss Dv: 0.10725151002407074, Loss Dc: 0.0507902167737484
# Epoch 30, Loss G: 5.323261737823486, Loss Dv: 0.028295671567320824, Loss Dc: 0.11092023551464081
# Epoch 30, Loss G: 4.932716369628906, Loss Dv: 0.11808463931083679, Loss Dc: 0.05921640619635582
# Epoch 30, Loss G: 4.646120071411133, Loss Dv: 0.2077009379863739, Loss Dc: 0.15364636480808258
# Epoch 30, Loss G: 4.1262335777282715, Loss Dv: 0.13131801784038544, Loss Dc: 0.1583593636751175
# Epoch 30, Loss G: 3.849543809890747, Loss Dv: 0.12618288397789001, Loss Dc: 0.07333549857139587
# Epoch 30, Loss G: 4.345828056335449, Loss Dv: 0.07786407321691513, Loss Dc: 0.06201567500829697
# Epoch 30, Loss G: 4.769928455352783, Loss Dv: 0.10592811554670334, Loss Dc: 0.24614986777305603
# Epoch 30, Loss G: 5.330234050750732, Loss Dv: 0.05652526766061783, Loss Dc: 0.0322112999856472
# Epoch 30, Loss G: 4.828014373779297, Loss Dv: 0.05416750907897949, Loss Dc: 0.04433056712150574
# Epoch 30, Loss G: 5.544806480407715, Loss Dv: 0.04418075829744339, Loss Dc: 0.02924005128443241
# Epoch 30, Loss G: 6.846867084503174, Loss Dv: 0.2323671579360962, Loss Dc: 0.06864854693412781
# Epoch 30, Loss G: 4.893854141235352, Loss Dv: 0.11740539968013763, Loss Dc: 0.02868536114692688
# Epoch 30, Loss G: 5.548459053039551, Loss Dv: 0.1139218807220459, Loss Dc: 0.12700515985488892
# Epoch 30, Loss G: 5.121297836303711, Loss Dv: 0.03594839572906494, Loss Dc: 0.16713127493858337
# Epoch 30, Loss G: 5.040144920349121, Loss Dv: 0.06736977398395538, Loss Dc: 0.02136790007352829
# Epoch 30, Loss G: 4.740522384643555, Loss Dv: 0.33699148893356323, Loss Dc: 0.04933759197592735
# Epoch 30, Loss G: 6.408792972564697, Loss Dv: 0.36562758684158325, Loss Dc: 0.02009338140487671
# Epoch 30, Loss G: 5.275818824768066, Loss Dv: 0.03809286653995514, Loss Dc: 0.038502585142850876
# Epoch 30, Loss G: 3.9318037033081055, Loss Dv: 0.05669306218624115, Loss Dc: 0.0617389976978302
# Epoch 30, Loss G: 5.639492988586426, Loss Dv: 0.02325323410332203, Loss Dc: 0.043477945029735565
# Epoch 30, Loss G: 4.431613445281982, Loss Dv: 0.027417277917265892, Loss Dc: 0.016965460032224655
# Epoch 30, Loss G: 5.009703159332275, Loss Dv: 0.10887490212917328, Loss Dc: 0.05954150855541229
# Epoch 30, Loss G: 3.9347589015960693, Loss Dv: 0.18394401669502258, Loss Dc: 0.028637249022722244
# Epoch 30, Loss G: 3.93868350982666, Loss Dv: 0.08740213513374329, Loss Dc: 0.01633811742067337
# Epoch 30, Loss G: 5.517255783081055, Loss Dv: 0.05673746019601822, Loss Dc: 0.03233414143323898
# Epoch 30, Loss G: 5.885788440704346, Loss Dv: 0.17015133798122406, Loss Dc: 0.018149483948946
# Epoch 30, Loss G: 7.175349712371826, Loss Dv: 0.05904649198055267, Loss Dc: 0.20471619069576263
# Epoch 30, Loss G: 4.090725421905518, Loss Dv: 0.1263580024242401, Loss Dc: 0.03400563821196556
# Epoch 30, Loss G: 4.352801322937012, Loss Dv: 0.13260625302791595, Loss Dc: 0.03922605514526367
# Epoch 30, Loss G: 4.12512731552124, Loss Dv: 0.1450628638267517, Loss Dc: 0.04164415970444679
# Epoch 30, Loss G: 4.612217903137207, Loss Dv: 0.042650215327739716, Loss Dc: 0.16012458503246307
# Epoch 30, Loss G: 3.277298927307129, Loss Dv: 0.12298750877380371, Loss Dc: 0.17756052315235138
# Epoch 30, Loss G: 3.3765697479248047, Loss Dv: 0.1302875280380249, Loss Dc: 0.24503113329410553
# Epoch 30, Loss G: 5.671523094177246, Loss Dv: 0.06972347944974899, Loss Dc: 0.02354198694229126
# Epoch 30, Loss G: 6.203349590301514, Loss Dv: 0.04061145707964897, Loss Dc: 0.12875165045261383
# Epoch 30, Loss G: 4.662362575531006, Loss Dv: 0.020694561302661896, Loss Dc: 0.010054747574031353
# Epoch 30, Loss G: 5.530197620391846, Loss Dv: 0.012428579851984978, Loss Dc: 0.025740962475538254
# Epoch 30, Loss G: 3.968003273010254, Loss Dv: 0.061789073050022125, Loss Dc: 0.06554526090621948
# Epoch 30, Loss G: 3.926682949066162, Loss Dv: 0.022143865004181862, Loss Dc: 0.013100222684442997
# Epoch 30, Loss G: 3.4994165897369385, Loss Dv: 0.06789041310548782, Loss Dc: 0.10542244464159012
# Epoch 30, Loss G: 3.4906163215637207, Loss Dv: 0.04113392531871796, Loss Dc: 0.1436253786087036
# Epoch 30, Loss G: 4.719101905822754, Loss Dv: 0.018039248883724213, Loss Dc: 0.03272708132863045
# Epoch 30, Loss G: 4.211644172668457, Loss Dv: 0.017413858324289322, Loss Dc: 0.08817730844020844
# Epoch 30, Loss G: 4.678418159484863, Loss Dv: 0.014046394266188145, Loss Dc: 0.26028910279273987
# Epoch 30, Loss G: 5.441920280456543, Loss Dv: 0.011686216108500957, Loss Dc: 0.06443166732788086
# Epoch 30, Loss G: 3.026564598083496, Loss Dv: 0.02697056345641613, Loss Dc: 0.16623081266880035
# Epoch 30, Loss G: 5.8908586502075195, Loss Dv: 0.027034297585487366, Loss Dc: 0.11743184924125671
# Epoch 30, Loss G: 4.4749956130981445, Loss Dv: 0.04328020662069321, Loss Dc: 0.20657607913017273
# Epoch 30, Loss G: 4.169367790222168, Loss Dv: 0.050086814910173416, Loss Dc: 0.08482207357883453
# Epoch 30, Loss G: 3.3221304416656494, Loss Dv: 0.037395890802145004, Loss Dc: 0.1131923645734787
# Epoch 30, Loss G: 6.170995235443115, Loss Dv: 0.012388900853693485, Loss Dc: 0.10644283890724182
# Epoch 30, Loss G: 4.866488456726074, Loss Dv: 0.020217834040522575, Loss Dc: 0.05630289763212204
# Epoch 30, Loss G: 3.151654005050659, Loss Dv: 0.30825477838516235, Loss Dc: 0.10795967280864716
# Epoch 30, Loss G: 3.766054153442383, Loss Dv: 0.1842450648546219, Loss Dc: 0.03290499746799469
# Epoch 30, Loss G: 3.9851162433624268, Loss Dv: 0.12368351221084595, Loss Dc: 0.1446557193994522
# Epoch 30, Loss G: 4.980370998382568, Loss Dv: 0.030858997255563736, Loss Dc: 0.1191224530339241
# Epoch 30, Loss G: 6.046787738800049, Loss Dv: 0.27215614914894104, Loss Dc: 0.03996479883790016
# Epoch 30, Loss G: 4.996138572692871, Loss Dv: 0.42284297943115234, Loss Dc: 0.0626504048705101
# Epoch 30, Loss G: 4.674671649932861, Loss Dv: 0.04783257097005844, Loss Dc: 0.07985948771238327
# Epoch 30, Loss G: 5.364137649536133, Loss Dv: 0.13943158090114594, Loss Dc: 0.02257133275270462
# Epoch 30, Loss G: 4.94682502746582, Loss Dv: 0.1404668092727661, Loss Dc: 0.17083051800727844
# Epoch 30, Loss G: 4.323553085327148, Loss Dv: 0.05606378614902496, Loss Dc: 0.017171313986182213
# Epoch 30, Loss G: 4.102675437927246, Loss Dv: 0.07908940315246582, Loss Dc: 0.0202479250729084
# Epoch 30, Loss G: 4.789145469665527, Loss Dv: 0.06349065899848938, Loss Dc: 0.046768419444561005
# Epoch 30, Loss G: 4.596041679382324, Loss Dv: 0.2833244502544403, Loss Dc: 0.13848677277565002
# Epoch 30, Loss G: 5.153959274291992, Loss Dv: 0.12161234766244888, Loss Dc: 0.152018740773201
# Epoch 30, Loss G: 2.8379549980163574, Loss Dv: 0.5102456212043762, Loss Dc: 0.12811794877052307
# Epoch 30, Loss G: 4.257430553436279, Loss Dv: 0.09346551448106766, Loss Dc: 0.16868676245212555
# Epoch 30, Loss G: 5.710369110107422, Loss Dv: 0.1125703901052475, Loss Dc: 0.04415449500083923
# Epoch 30, Loss G: 7.555150508880615, Loss Dv: 0.03729347884654999, Loss Dc: 0.011234678328037262
# Epoch 30, Loss G: 3.9558606147766113, Loss Dv: 0.10082949697971344, Loss Dc: 0.018105605617165565
# Epoch 30, Loss G: 4.880128860473633, Loss Dv: 0.08794879913330078, Loss Dc: 0.03231640160083771
# Epoch 30, Loss G: 4.4701642990112305, Loss Dv: 0.03920355439186096, Loss Dc: 0.17649716138839722
# Epoch 30, Loss G: 5.31821346282959, Loss Dv: 0.026059605181217194, Loss Dc: 0.20640744268894196
# Epoch 30, Loss G: 4.461446285247803, Loss Dv: 0.11731947213411331, Loss Dc: 0.05741187185049057
# Epoch 30, Loss G: 4.746740818023682, Loss Dv: 0.06169625744223595, Loss Dc: 0.05282185971736908
# Epoch 30, Loss G: 3.0456442832946777, Loss Dv: 0.0440911203622818, Loss Dc: 0.07635551691055298
# Epoch 30, Loss G: 3.6431140899658203, Loss Dv: 0.18839511275291443, Loss Dc: 0.026926027610898018
# Epoch 30, Loss G: 4.2758612632751465, Loss Dv: 0.16079013049602509, Loss Dc: 0.27853941917419434
# Epoch 30, Loss G: 4.153294086456299, Loss Dv: 0.15703141689300537, Loss Dc: 0.15715788304805756
# Epoch 30, Loss G: 4.518243789672852, Loss Dv: 0.151879221200943, Loss Dc: 0.03745449334383011
# Epoch 30, Loss G: 6.605052471160889, Loss Dv: 0.06909942626953125, Loss Dc: 0.013854045420885086
# Epoch 30, Loss G: 5.5163750648498535, Loss Dv: 0.03658692538738251, Loss Dc: 0.09366545081138611
# Epoch 30, Loss G: 4.162396430969238, Loss Dv: 0.07396334409713745, Loss Dc: 0.04027234762907028
# Epoch 30, Loss G: 5.485248565673828, Loss Dv: 0.05378514900803566, Loss Dc: 0.051350004971027374
# Epoch 30, Loss G: 6.644908428192139, Loss Dv: 0.06809806078672409, Loss Dc: 0.018764637410640717
# Epoch 30, Loss G: 5.080110549926758, Loss Dv: 0.0407891571521759, Loss Dc: 0.14678911864757538
# Epoch 30, Loss G: 2.7977547645568848, Loss Dv: 0.07620643079280853, Loss Dc: 0.15460649132728577
# Epoch 30, Loss G: 4.514619827270508, Loss Dv: 0.07096877694129944, Loss Dc: 0.0723685622215271
# Epoch 30, Loss G: 3.0616981983184814, Loss Dv: 0.1773603856563568, Loss Dc: 0.3865501880645752
# Epoch 30, Loss G: 4.180756092071533, Loss Dv: 0.16275916993618011, Loss Dc: 0.5947015285491943
# Epoch 30, Loss G: 3.1905529499053955, Loss Dv: 0.03400709852576256, Loss Dc: 0.26919299364089966
# Epoch 30, Loss G: 3.9888718128204346, Loss Dv: 0.03384443372488022, Loss Dc: 0.11810889840126038
# Epoch 30, Loss G: 4.699227809906006, Loss Dv: 0.026586458086967468, Loss Dc: 0.04050949215888977
# Epoch 30, Loss G: 4.802867412567139, Loss Dv: 0.03086680918931961, Loss Dc: 0.03718942031264305
# Epoch 40, Loss G: 3.474179267883301, Loss Dv: 0.06204785406589508, Loss Dc: 0.01626746729016304
# Epoch 40, Loss G: 4.111667633056641, Loss Dv: 0.056136734783649445, Loss Dc: 0.06401592493057251
# Epoch 40, Loss G: 4.554915904998779, Loss Dv: 0.03330174461007118, Loss Dc: 0.03040730208158493
# Epoch 40, Loss G: 3.7897844314575195, Loss Dv: 0.03017266094684601, Loss Dc: 0.09109151363372803
# Epoch 40, Loss G: 4.290511131286621, Loss Dv: 0.08742935955524445, Loss Dc: 0.43223118782043457
# Epoch 40, Loss G: 4.689561367034912, Loss Dv: 0.018208414316177368, Loss Dc: 0.06250473111867905
# Epoch 40, Loss G: 4.892794609069824, Loss Dv: 0.24107380211353302, Loss Dc: 0.1658807098865509
# Epoch 40, Loss G: 3.482248544692993, Loss Dv: 0.06973487138748169, Loss Dc: 0.0847768634557724
# Epoch 40, Loss G: 3.6971991062164307, Loss Dv: 0.05913498252630234, Loss Dc: 0.058830078691244125
# Epoch 40, Loss G: 4.458512306213379, Loss Dv: 0.18959712982177734, Loss Dc: 0.043394785374403
# Epoch 40, Loss G: 5.663804054260254, Loss Dv: 0.040542520582675934, Loss Dc: 0.029592586681246758
# Epoch 40, Loss G: 4.907238483428955, Loss Dv: 0.08687333762645721, Loss Dc: 0.008854049257934093
# Epoch 40, Loss G: 3.9696502685546875, Loss Dv: 0.10202331095933914, Loss Dc: 0.03756412863731384
# Epoch 40, Loss G: 4.833949565887451, Loss Dv: 0.021442322060465813, Loss Dc: 0.08373530954122543
# Epoch 40, Loss G: 4.0948872566223145, Loss Dv: 0.026309622451663017, Loss Dc: 0.03382975235581398
# Epoch 40, Loss G: 3.407435655593872, Loss Dv: 0.028553687036037445, Loss Dc: 0.07234470546245575
# Epoch 40, Loss G: 4.239846706390381, Loss Dv: 0.06343274563550949, Loss Dc: 0.09258183091878891
# Epoch 40, Loss G: 4.610091209411621, Loss Dv: 0.059046559035778046, Loss Dc: 0.07080254703760147
# Epoch 40, Loss G: 5.798802375793457, Loss Dv: 0.015822479501366615, Loss Dc: 0.10283643752336502
# Epoch 40, Loss G: 5.8030476570129395, Loss Dv: 0.04706825315952301, Loss Dc: 0.017889942973852158
# Epoch 40, Loss G: 5.405320167541504, Loss Dv: 0.22026139497756958, Loss Dc: 0.011556755751371384
# Epoch 40, Loss G: 4.2487053871154785, Loss Dv: 0.029235433787107468, Loss Dc: 0.025644753128290176
# Epoch 40, Loss G: 6.675113201141357, Loss Dv: 0.0713106319308281, Loss Dc: 0.20090341567993164
# Epoch 40, Loss G: 4.82966423034668, Loss Dv: 0.08459452539682388, Loss Dc: 0.06102656573057175
# Epoch 40, Loss G: 5.178277492523193, Loss Dv: 0.0801776722073555, Loss Dc: 0.07283443212509155
# Epoch 40, Loss G: 3.4979395866394043, Loss Dv: 0.20614269375801086, Loss Dc: 0.25769945979118347
# Epoch 40, Loss G: 4.366247653961182, Loss Dv: 0.10541976243257523, Loss Dc: 0.2016502022743225
# Epoch 40, Loss G: 4.498250484466553, Loss Dv: 0.05529172718524933, Loss Dc: 0.022636324167251587
# Epoch 40, Loss G: 4.394740581512451, Loss Dv: 0.03459911793470383, Loss Dc: 0.015327832661569118
# Epoch 40, Loss G: 3.635991334915161, Loss Dv: 0.04187902808189392, Loss Dc: 0.09848117083311081
# Epoch 40, Loss G: 5.796375274658203, Loss Dv: 0.030607014894485474, Loss Dc: 0.159772127866745
# Epoch 40, Loss G: 3.9305436611175537, Loss Dv: 0.054632335901260376, Loss Dc: 0.08941638469696045
# Epoch 40, Loss G: 3.717578411102295, Loss Dv: 0.0645667016506195, Loss Dc: 0.11525376886129379
# Epoch 40, Loss G: 5.164696216583252, Loss Dv: 0.2066260576248169, Loss Dc: 0.06653125584125519
# Epoch 40, Loss G: 6.145194053649902, Loss Dv: 0.06299969553947449, Loss Dc: 0.07138902693986893
# Epoch 40, Loss G: 5.515985488891602, Loss Dv: 0.12609034776687622, Loss Dc: 0.4005037844181061
# Epoch 40, Loss G: 3.4437148571014404, Loss Dv: 0.055016808211803436, Loss Dc: 0.21060577034950256
# Epoch 40, Loss G: 4.416299343109131, Loss Dv: 0.24026906490325928, Loss Dc: 0.15533921122550964
# Epoch 40, Loss G: 2.943108320236206, Loss Dv: 0.24592822790145874, Loss Dc: 0.10447828471660614
# Epoch 40, Loss G: 4.136738300323486, Loss Dv: 0.054464299231767654, Loss Dc: 0.06166849657893181
# Epoch 40, Loss G: 3.5242843627929688, Loss Dv: 0.04297059774398804, Loss Dc: 0.21953964233398438
# Epoch 40, Loss G: 5.183238983154297, Loss Dv: 0.06866977363824844, Loss Dc: 0.1265573650598526
# Epoch 40, Loss G: 4.209635257720947, Loss Dv: 0.09744901955127716, Loss Dc: 0.03967190533876419
# Epoch 40, Loss G: 4.479499340057373, Loss Dv: 0.04129277914762497, Loss Dc: 0.05264398455619812
# Epoch 40, Loss G: 4.327049255371094, Loss Dv: 0.05603782832622528, Loss Dc: 0.40663692355155945
# ...
# Epoch 80, Loss G: 3.4884729385375977, Loss Dv: 0.016139959916472435, Loss Dc: 0.021663282066583633
# Epoch 80, Loss G: 5.311547756195068, Loss Dv: 0.022016996517777443, Loss Dc: 0.032259970903396606
# Epoch 80, Loss G: 3.719428777694702, Loss Dv: 0.06725803762674332, Loss Dc: 0.10057134181261063
# Epoch 80, Loss G: 5.750076770782471, Loss Dv: 0.061952851712703705, Loss Dc: 0.09581758081912994
# Epoch 80, Loss G: 6.067068576812744, Loss Dv: 0.018283575773239136, Loss Dc: 0.06959622353315353
# Epoch 80, Loss G: 4.143204212188721, Loss Dv: 0.02233506739139557, Loss Dc: 0.03919176012277603
# Epoch 80, Loss G: 3.468256711959839, Loss Dv: 0.09050256013870239, Loss Dc: 0.04711497575044632
# Epoch 80, Loss G: 5.298948764801025, Loss Dv: 0.11363356560468674, Loss Dc: 0.06582464277744293
# Epoch 80, Loss G: 4.582178115844727, Loss Dv: 0.04468492418527603, Loss Dc: 0.017755016684532166
# Epoch 80, Loss G: 4.190057754516602, Loss Dv: 0.06951899081468582, Loss Dc: 0.017162535339593887
# Epoch 80, Loss G: 4.193448543548584, Loss Dv: 0.07383313030004501, Loss Dc: 0.12973551452159882
# Epoch 80, Loss G: 5.47972297668457, Loss Dv: 0.057649992406368256, Loss Dc: 0.026698201894760132
# Epoch 80, Loss G: 4.4114227294921875, Loss Dv: 0.039105452597141266, Loss Dc: 0.04203382506966591
# Epoch 80, Loss G: 6.756326675415039, Loss Dv: 0.03748760372400284, Loss Dc: 0.0233682319521904
# Epoch 80, Loss G: 3.451286792755127, Loss Dv: 0.1230953112244606, Loss Dc: 0.024685515090823174
# Epoch 80, Loss G: 3.573563814163208, Loss Dv: 0.031321536749601364, Loss Dc: 0.03523481264710426
# Epoch 80, Loss G: 3.82218074798584, Loss Dv: 0.13159669935703278, Loss Dc: 0.005549575202167034
# Epoch 80, Loss G: 4.511020660400391, Loss Dv: 0.047346506267786026, Loss Dc: 0.013733722269535065
# Epoch 80, Loss G: 3.7537643909454346, Loss Dv: 0.14747849106788635, Loss Dc: 0.03565289080142975
# Epoch 80, Loss G: 2.7173852920532227, Loss Dv: 0.1257953643798828, Loss Dc: 0.029662471264600754
# Epoch 80, Loss G: 4.359106063842773, Loss Dv: 0.0619087852537632, Loss Dc: 0.055490054190158844
# Epoch 80, Loss G: 3.729442834854126, Loss Dv: 0.1034710556268692, Loss Dc: 0.025012673810124397
# Epoch 80, Loss G: 3.4768660068511963, Loss Dv: 0.1179855540394783, Loss Dc: 0.016341816633939743
# Epoch 80, Loss G: 4.645459175109863, Loss Dv: 0.029355036094784737, Loss Dc: 0.032975904643535614
# Epoch 80, Loss G: 5.182446479797363, Loss Dv: 0.19184786081314087, Loss Dc: 0.03174545243382454
# Epoch 80, Loss G: 3.222362756729126, Loss Dv: 0.12723302841186523, Loss Dc: 0.05003228783607483
# Epoch 80, Loss G: 4.127368450164795, Loss Dv: 0.05130528658628464, Loss Dc: 0.03564724698662758
# Epoch 80, Loss G: 5.397057056427002, Loss Dv: 0.016761627048254013, Loss Dc: 0.0327853225171566
# Epoch 80, Loss G: 4.35190486907959, Loss Dv: 0.039794906973838806, Loss Dc: 0.04144490510225296
# Epoch 80, Loss G: 3.412959337234497, Loss Dv: 0.07381793856620789, Loss Dc: 0.023502785712480545
# Epoch 80, Loss G: 4.238268852233887, Loss Dv: 0.020103031769394875, Loss Dc: 0.05162204056978226
# Epoch 80, Loss G: 6.775390625, Loss Dv: 0.06948030740022659, Loss Dc: 0.09502605348825455
# Epoch 80, Loss G: 5.2228288650512695, Loss Dv: 0.02490054816007614, Loss Dc: 0.03181416913866997
# Epoch 80, Loss G: 4.635036945343018, Loss Dv: 0.04198215529322624, Loss Dc: 0.06602136790752411
# Epoch 80, Loss G: 5.546215534210205, Loss Dv: 0.04271235316991806, Loss Dc: 0.05059207230806351
# Epoch 80, Loss G: 4.466108322143555, Loss Dv: 0.04252748191356659, Loss Dc: 0.05214602127671242
# Epoch 80, Loss G: 3.9843645095825195, Loss Dv: 0.016710227355360985, Loss Dc: 0.03156426548957825
# Epoch 80, Loss G: 4.03384256362915, Loss Dv: 0.059127189218997955, Loss Dc: 0.022959519177675247
# Epoch 80, Loss G: 4.215134620666504, Loss Dv: 0.03101695328950882, Loss Dc: 0.038631871342659
# Epoch 80, Loss G: 5.017996311187744, Loss Dv: 0.02200261503458023, Loss Dc: 0.021648671478033066
# Epoch 80, Loss G: 3.206514358520508, Loss Dv: 0.06974279135465622, Loss Dc: 0.032517608255147934
# Epoch 80, Loss G: 4.714564323425293, Loss Dv: 0.05020517110824585, Loss Dc: 0.022788451984524727
# Epoch 80, Loss G: 3.4551048278808594, Loss Dv: 0.0785326287150383, Loss Dc: 0.05904504656791687
# Epoch 80, Loss G: 3.1283769607543945, Loss Dv: 0.09719470143318176, Loss Dc: 0.06427521258592606
# Epoch 80, Loss G: 7.041752338409424, Loss Dv: 0.060974374413490295, Loss Dc: 0.025488197803497314
# Epoch 80, Loss G: 3.274437189102173, Loss Dv: 0.05428307130932808, Loss Dc: 0.0493687242269516
# Epoch 80, Loss G: 4.07852029800415, Loss Dv: 0.07545553892850876, Loss Dc: 0.03549399599432945
# Epoch 80, Loss G: 4.629023551940918, Loss Dv: 0.03932281583547592, Loss Dc: 0.09538736194372177
# Epoch 80, Loss G: 5.842724323272705, Loss Dv: 0.05171913653612137, Loss Dc: 0.07796677201986313
# Epoch 80, Loss G: 6.24768590927124, Loss Dv: 0.028848271816968918, Loss Dc: 0.0115021001547575
# Epoch 80, Loss G: 4.269455909729004, Loss Dv: 0.0711221694946289, Loss Dc: 0.025327984243631363
# Epoch 90, Loss G: 3.367072820663452, Loss Dv: 0.035843681544065475, Loss Dc: 0.11441633105278015
# Epoch 90, Loss G: 2.7973597049713135, Loss Dv: 0.14756929874420166, Loss Dc: 0.07143085449934006
# Epoch 90, Loss G: 3.176023006439209, Loss Dv: 0.025843366980552673, Loss Dc: 0.07783135771751404
# Epoch 90, Loss G: 5.369447231292725, Loss Dv: 0.06967904418706894, Loss Dc: 0.045300886034965515
# Epoch 90, Loss G: 4.625306129455566, Loss Dv: 0.07711678743362427, Loss Dc: 0.021278779953718185
# Epoch 90, Loss G: 3.612793445587158, Loss Dv: 0.06126021593809128, Loss Dc: 0.012150825932621956
# Epoch 90, Loss G: 6.6730732917785645, Loss Dv: 0.16289305686950684, Loss Dc: 0.09733322262763977
# Epoch 90, Loss G: 4.411458492279053, Loss Dv: 0.1118641123175621, Loss Dc: 0.06344515830278397
# Epoch 90, Loss G: 3.993791341781616, Loss Dv: 0.03242141380906105, Loss Dc: 0.0780760869383812
# Epoch 90, Loss G: 4.771760940551758, Loss Dv: 0.02314358949661255, Loss Dc: 0.09957200288772583
# Epoch 90, Loss G: 5.298391819000244, Loss Dv: 0.08126566559076309, Loss Dc: 0.03695189952850342
# Epoch 90, Loss G: 3.6763839721679688, Loss Dv: 0.12803393602371216, Loss Dc: 0.10965435951948166
# Epoch 90, Loss G: 4.41071891784668, Loss Dv: 0.043830715119838715, Loss Dc: 0.03087392821907997
# Epoch 90, Loss G: 4.351635456085205, Loss Dv: 0.029441848397254944, Loss Dc: 0.12858250737190247
# Epoch 90, Loss G: 3.472041606903076, Loss Dv: 0.046508803963661194, Loss Dc: 0.02667314000427723
# Epoch 90, Loss G: 4.087368011474609, Loss Dv: 0.02754325419664383, Loss Dc: 0.07736976444721222
# Epoch 90, Loss G: 5.854759216308594, Loss Dv: 0.06429997086524963, Loss Dc: 0.013996580615639687
# Epoch 90, Loss G: 4.261538505554199, Loss Dv: 0.03350314870476723, Loss Dc: 0.023927614092826843
# Epoch 90, Loss G: 5.42838191986084, Loss Dv: 0.05423761159181595, Loss Dc: 0.06351807713508606
# Epoch 90, Loss G: 6.483930587768555, Loss Dv: 0.034890834242105484, Loss Dc: 0.02018197439610958
# Epoch 90, Loss G: 5.300045967102051, Loss Dv: 0.08118697255849838, Loss Dc: 0.03680788725614548
# Epoch 90, Loss G: 4.346661567687988, Loss Dv: 0.03226880729198456, Loss Dc: 0.015665274113416672
# Epoch 90, Loss G: 5.110489845275879, Loss Dv: 0.022339804098010063, Loss Dc: 0.010117348283529282
# Epoch 90, Loss G: 3.9576380252838135, Loss Dv: 0.02538825199007988, Loss Dc: 0.02300957217812538
# Epoch 90, Loss G: 6.327260494232178, Loss Dv: 0.027978911995887756, Loss Dc: 0.020343763753771782
# Epoch 90, Loss G: 4.880876541137695, Loss Dv: 0.060448601841926575, Loss Dc: 0.011874017305672169
# Epoch 90, Loss G: 4.6571946144104, Loss Dv: 0.010341600514948368, Loss Dc: 0.02060442604124546
# Epoch 90, Loss G: 4.2946062088012695, Loss Dv: 0.013238254934549332, Loss Dc: 0.010784627869725227
# Epoch 90, Loss G: 4.418332576751709, Loss Dv: 0.014902148395776749, Loss Dc: 0.006292639300227165
# Epoch 90, Loss G: 5.613142013549805, Loss Dv: 0.018162589520215988, Loss Dc: 0.0215144120156765
# Epoch 90, Loss G: 3.95963978767395, Loss Dv: 0.05534697324037552, Loss Dc: 0.00814823154360056
# Epoch 90, Loss G: 4.2020182609558105, Loss Dv: 0.05063352733850479, Loss Dc: 0.010992338880896568
# Epoch 90, Loss G: 3.6713390350341797, Loss Dv: 0.04626919701695442, Loss Dc: 0.017435066401958466
# Epoch 90, Loss G: 4.502443313598633, Loss Dv: 0.026210270822048187, Loss Dc: 0.02269185706973076
# Epoch 90, Loss G: 4.1042985916137695, Loss Dv: 0.030607186257839203, Loss Dc: 0.02284032106399536
# Epoch 90, Loss G: 6.080933570861816, Loss Dv: 0.017624780535697937, Loss Dc: 0.004641888663172722
# Epoch 90, Loss G: 4.656288146972656, Loss Dv: 0.027098171412944794, Loss Dc: 0.005463995970785618
# Epoch 90, Loss G: 3.5056166648864746, Loss Dv: 0.09619949012994766, Loss Dc: 0.004504154436290264
# Epoch 90, Loss G: 3.566525936126709, Loss Dv: 0.01537436991930008, Loss Dc: 0.008525512181222439
# Epoch 90, Loss G: 3.6716623306274414, Loss Dv: 0.06135578081011772, Loss Dc: 0.01593608595430851
# Epoch 90, Loss G: 4.7765960693359375, Loss Dv: 0.016391003504395485, Loss Dc: 0.004084497224539518
# Epoch 90, Loss G: 4.203895568847656, Loss Dv: 0.08287983387708664, Loss Dc: 0.07288316637277603
# Epoch 90, Loss G: 4.625750541687012, Loss Dv: 0.014876021072268486, Loss Dc: 0.012166136875748634
# Epoch 90, Loss G: 4.869103908538818, Loss Dv: 0.023138560354709625, Loss Dc: 0.06202046945691109
# Epoch 90, Loss G: 4.617401123046875, Loss Dv: 0.05532342195510864, Loss Dc: 0.02226010337471962
# Epoch 90, Loss G: 4.549189567565918, Loss Dv: 0.09032654762268066, Loss Dc: 0.02852041833102703
# Epoch 90, Loss G: 3.364424228668213, Loss Dv: 0.07497598975896835, Loss Dc: 0.012146547436714172
# Epoch 90, Loss G: 4.605585098266602, Loss Dv: 0.05648372694849968, Loss Dc: 0.014173120260238647
# Epoch 90, Loss G: 2.5413341522216797, Loss Dv: 0.06977954506874084, Loss Dc: 0.03453023359179497
# Epoch 90, Loss G: 4.958178997039795, Loss Dv: 0.0328272320330143, Loss Dc: 0.008705757558345795
# Epoch 90, Loss G: 3.768608570098877, Loss Dv: 0.08351223915815353, Loss Dc: 0.02019188553094864
# Epoch 90, Loss G: 3.440506935119629, Loss Dv: 0.023078665137290955, Loss Dc: 0.05423933267593384
# Epoch 90, Loss G: 3.6038405895233154, Loss Dv: 0.10729282349348068, Loss Dc: 0.02157856896519661
# Epoch 90, Loss G: 6.082129001617432, Loss Dv: 0.04183134064078331, Loss Dc: 0.04144604876637459
# Epoch 90, Loss G: 3.574836254119873, Loss Dv: 0.03372390940785408, Loss Dc: 0.016875891014933586
# Epoch 90, Loss G: 2.4299330711364746, Loss Dv: 0.05210898444056511, Loss Dc: 0.08039949834346771
# Epoch 90, Loss G: 4.0301361083984375, Loss Dv: 0.05233479291200638, Loss Dc: 0.17175878584384918
# Epoch 90, Loss G: 3.3698408603668213, Loss Dv: 0.025647073984146118, Loss Dc: 0.024929124861955643
# Epoch 90, Loss G: 3.4786527156829834, Loss Dv: 0.020736385136842728, Loss Dc: 0.08778518438339233
# Epoch 90, Loss G: 3.303379774093628, Loss Dv: 0.026527436450123787, Loss Dc: 0.020605377852916718
# Epoch 90, Loss G: 4.641812324523926, Loss Dv: 0.033252354711294174, Loss Dc: 0.03186069801449776
# Epoch 90, Loss G: 3.6250758171081543, Loss Dv: 0.05947817489504814, Loss Dc: 0.02111820876598358
# Epoch 90, Loss G: 3.4737274646759033, Loss Dv: 0.0144271831959486, Loss Dc: 0.035231079906225204
# Epoch 90, Loss G: 4.387138843536377, Loss Dv: 0.01197787094861269, Loss Dc: 0.011937199160456657
# Epoch 90, Loss G: 3.3663177490234375, Loss Dv: 0.019707564264535904, Loss Dc: 0.08704161643981934
# Epoch 90, Loss G: 3.6763947010040283, Loss Dv: 0.02232968807220459, Loss Dc: 0.041947558522224426
# Epoch 90, Loss G: 3.1681387424468994, Loss Dv: 0.05687982961535454, Loss Dc: 0.025825537741184235
# Epoch 90, Loss G: 3.262909412384033, Loss Dv: 0.024725819006562233, Loss Dc: 0.03624701499938965
# Epoch 90, Loss G: 4.517966270446777, Loss Dv: 0.04770248383283615, Loss Dc: 0.018646132200956345
# Epoch 90, Loss G: 3.7784063816070557, Loss Dv: 0.03647182881832123, Loss Dc: 0.034496914595365524
# Epoch 90, Loss G: 4.341437339782715, Loss Dv: 0.03978333622217178, Loss Dc: 0.028066733852028847
# Epoch 90, Loss G: 5.220579624176025, Loss Dv: 0.03151099383831024, Loss Dc: 0.049208879470825195
# Epoch 90, Loss G: 5.041293144226074, Loss Dv: 0.02672085165977478, Loss Dc: 0.04243571311235428
# Epoch 90, Loss G: 2.800416946411133, Loss Dv: 0.061655014753341675, Loss Dc: 0.07172463834285736
# Epoch 90, Loss G: 4.670644760131836, Loss Dv: 0.016832541674375534, Loss Dc: 0.016728561371564865
# Epoch 90, Loss G: 3.0709171295166016, Loss Dv: 0.05814250558614731, Loss Dc: 0.017901215702295303
# Epoch 90, Loss G: 2.8391125202178955, Loss Dv: 0.05740581452846527, Loss Dc: 0.023044148460030556
# Epoch 90, Loss G: 5.469306945800781, Loss Dv: 0.053073398768901825, Loss Dc: 0.00939333438873291
# Epoch 90, Loss G: 4.784395694732666, Loss Dv: 0.013009436428546906, Loss Dc: 0.04713129997253418
# Epoch 90, Loss G: 3.3512420654296875, Loss Dv: 0.040186215192079544, Loss Dc: 0.02272574044764042
# Epoch 90, Loss G: 5.843751907348633, Loss Dv: 0.02211962454020977, Loss Dc: 0.022973287850618362
# Epoch 90, Loss G: 4.970798492431641, Loss Dv: 0.0458286888897419, Loss Dc: 0.02113230526447296
# Epoch 90, Loss G: 5.939415454864502, Loss Dv: 0.027317937463521957, Loss Dc: 0.01786520890891552
# Epoch 90, Loss G: 3.812084436416626, Loss Dv: 0.015278334729373455, Loss Dc: 0.024744171649217606
# Epoch 90, Loss G: 4.444922924041748, Loss Dv: 0.009795422665774822, Loss Dc: 0.05709102377295494
# Epoch 90, Loss G: 3.5301716327667236, Loss Dv: 0.08049911260604858, Loss Dc: 0.019765891134738922
# Epoch 90, Loss G: 4.029864311218262, Loss Dv: 0.08336491137742996, Loss Dc: 0.011785837821662426
# Epoch 90, Loss G: 5.079848766326904, Loss Dv: 0.11141230165958405, Loss Dc: 0.010041776113212109
# Epoch 90, Loss G: 6.316186428070068, Loss Dv: 0.04502825438976288, Loss Dc: 0.00733980443328619
# Epoch 90, Loss G: 5.12449836730957, Loss Dv: 0.10123898088932037, Loss Dc: 0.008279023692011833
# Epoch 90, Loss G: 5.712111473083496, Loss Dv: 0.053778063505887985, Loss Dc: 0.010040570981800556
# Epoch 90, Loss G: 4.743496894836426, Loss Dv: 0.03941623866558075, Loss Dc: 0.007385415956377983
# Epoch 90, Loss G: 3.021623134613037, Loss Dv: 0.030737191438674927, Loss Dc: 0.03905775770545006
# Epoch 90, Loss G: 5.115016937255859, Loss Dv: 0.040608540177345276, Loss Dc: 0.012983595952391624
# Epoch 90, Loss G: 4.615747928619385, Loss Dv: 0.04270217940211296, Loss Dc: 0.0314357690513134
# Epoch 90, Loss G: 5.426514625549316, Loss Dv: 0.03180427849292755, Loss Dc: 0.05948646366596222
# Epoch 90, Loss G: 4.907041549682617, Loss Dv: 0.07021815329790115, Loss Dc: 0.026529138907790184
# Epoch 90, Loss G: 4.920141220092773, Loss Dv: 0.06339220702648163, Loss Dc: 0.019808214157819748
# Epoch 90, Loss G: 4.415842056274414, Loss Dv: 0.027948083356022835, Loss Dc: 0.013285033404827118
# Epoch 90, Loss G: 4.669840335845947, Loss Dv: 0.021420778706669807, Loss Dc: 0.014898906461894512
# Epoch 90, Loss G: 3.8342161178588867, Loss Dv: 0.07876993715763092, Loss Dc: 0.040367912501096725
# Epoch 90, Loss G: 4.743061542510986, Loss Dv: 0.03719394654035568, Loss Dc: 0.03171699121594429
# Epoch 90, Loss G: 4.372223854064941, Loss Dv: 0.026941638439893723, Loss Dc: 0.02378241904079914
# Epoch 90, Loss G: 4.26617956161499, Loss Dv: 0.03930996358394623, Loss Dc: 0.021715817973017693
# Epoch 90, Loss G: 4.449835777282715, Loss Dv: 0.021654712036252022, Loss Dc: 0.01645311713218689
# Epoch 90, Loss G: 3.6792666912078857, Loss Dv: 0.01631922647356987, Loss Dc: 0.07610020786523819
# Epoch 90, Loss G: 3.636805534362793, Loss Dv: 0.09680378437042236, Loss Dc: 0.06312934309244156
# Epoch 90, Loss G: 5.204116344451904, Loss Dv: 0.14251363277435303, Loss Dc: 0.0203646719455719
# Epoch 90, Loss G: 5.898836135864258, Loss Dv: 0.056088969111442566, Loss Dc: 0.043348219245672226
# Epoch 90, Loss G: 3.7845206260681152, Loss Dv: 0.07285421341657639, Loss Dc: 0.04615257307887077
# Epoch 90, Loss G: 4.769139766693115, Loss Dv: 0.036341965198516846, Loss Dc: 0.020553650334477425
# Epoch 90, Loss G: 6.815101623535156, Loss Dv: 0.11705738306045532, Loss Dc: 0.03942974656820297
# Epoch 90, Loss G: 5.063365459442139, Loss Dv: 0.0348791629076004, Loss Dc: 0.04877299815416336
# Epoch 90, Loss G: 5.492411136627197, Loss Dv: 0.02799718827009201, Loss Dc: 0.012397615239024162

# %%
#cycle final
import torch
import numpy as np
from PIL import Image
import os
import torch.nn as nn
from torchvision.transforms import ToTensor, ToPILImage


# os.makedirs('/content/drive/MyDrive/output2_final', exist_ok=True)
class ResNetBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ResNetBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1)
        self.in1 = nn.InstanceNorm2d(out_channels, affine=True)
        self.relu = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1)
        self.in2 = nn.InstanceNorm2d(out_channels, affine=True)

    def forward(self, x):
        residual = x
        out = self.conv1(x)
        out = self.in1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.in2(out)
        return out + residual

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.initial = nn.Conv2d(3, 64, kernel_size=7, padding=3)
        self.initial_in = nn.InstanceNorm2d(64, affine=True)
        self.initial_relu = nn.ReLU(inplace=True)
        self.res_blocks = nn.Sequential(*[ResNetBlock(64, 64) for _ in range(9)])
        self.final = nn.Conv2d(64, 3, kernel_size=7, padding=3)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.initial_relu(self.initial_in(self.initial(x)))
        features = self.res_blocks(x)
        x = self.tanh(self.final(features))
        return x


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

Gv2c = Generator().to(device)  # Vintage to Contemporary
Gc2v = Generator().to(device)  # Contemporary to Vintage

Gv2c.load_state_dict(torch.load('/content/drive/MyDrive/output/Gv2c.pth', map_location=device))
Gc2v.load_state_dict(torch.load('/content/drive/MyDrive/output/Gc2v.pth', map_location=device))

Gv2c.eval()
Gc2v.eval()


def load_image(image_path, size=None):
    
    image = Image.open(image_path).convert('RGB')
    if size:
        image = image.resize(size)
    return image

def save_image(image, output_path):
  
    image.save(output_path)

def transform_image(image):
    transform = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    return transform(image).unsqueeze(0).to(device)

def tensor_to_image(tensor):
    tensor = tensor.squeeze().cpu().detach()
    transform = transforms.ToPILImage()
    return transform(tensor)

def apply_cycle_gan_transform(image_path, generator, target_size=(256, 256)):
    image = load_image(image_path, size=target_size)
    input_image = transform_image(image)

    with torch.no_grad():
        output_image = generator(input_image)

    return tensor_to_image(output_image)

base_image_path = '/content/drive/MyDrive/contemporary_images/c2.png'
pattern_image_path = '/content/drive/MyDrive/vintage_images/v32.png'
output_path = '/content/drive/MyDrive/output2_final/new2.png'


transformed_base_image = apply_cycle_gan_transform(base_image_path, Gv2c)
transformed_pattern_image = apply_cycle_gan_transform(pattern_image_path, Gc2v)


base_image_np = np.array(transformed_base_image)
pattern_image_np = np.array(transformed_pattern_image)

def blend_images(base_image_array, pattern_image_array, alpha=0.5):
    base_image_array = base_image_array.astype(float)
    pattern_image_array = pattern_image_array.astype(float)

    # Normalize pattern to be in range [0, 255]
    pattern_normalized = (pattern_image_array / pattern_image_array.max()) * 255
    pattern_normalized = np.clip(pattern_normalized, 0, 255)

    # Blend the pattern with the base image
    blended_image = base_image_array * (1 - alpha) + pattern_normalized * alpha
    blended_image = np.clip(blended_image, 0, 255)

    return Image.fromarray(blended_image.astype('uint8'))

blended_with_pattern_image = blend_images(base_image_np, pattern_image_np)

save_image(blended_with_pattern_image, output_path)
# Out:
# <ipython-input-10-a1da28512c44>:50: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Gv2c.load_state_dict(torch.load('/content/drive/MyDrive/output/Gv2c.pth', map_location=device))
# <ipython-input-10-a1da28512c44>:51: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Gc2v.load_state_dict(torch.load('/content/drive/MyDrive/output/Gc2v.pth', map_location=device))

# %%
#cycle f2
import torch
import numpy as np
from PIL import Image, ImageFilter
import os
from torchvision import transforms
from torchvision.utils import save_image

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.initial = nn.Conv2d(3, 64, kernel_size=7, padding=3)
        self.initial_in = nn.InstanceNorm2d(64, affine=True)
        self.initial_relu = nn.ReLU(inplace=True)
        self.res_blocks = nn.Sequential(*[ResNetBlock(64, 64) for _ in range(9)])
        self.final = nn.Conv2d(64, 3, kernel_size=7, padding=3)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x = self.initial_relu(self.initial_in(self.initial(x)))
        features = self.res_blocks(x)
        x = self.tanh(self.final(features))
        return x


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

Gv2c = Generator().to(device)  # Vintage to Contemporary
Gc2v = Generator().to(device)  # Contemporary to Vintage

Gv2c.load_state_dict(torch.load('/content/drive/MyDrive/output/Gv2c.pth', map_location=device))
Gc2v.load_state_dict(torch.load('/content/drive/MyDrive/output/Gc2v.pth', map_location=device))

Gv2c.eval()
Gc2v.eval()


def load_image(image_path, size=None):
    image = Image.open(image_path).convert('RGB')
    if size:
        image = image.resize(size)
    return image

def save_image(image_array, output_path):
    image = Image.fromarray(image_array.astype('uint8'))
    image.save(output_path)

def transform_image(image, generator):
    transform = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    image_tensor = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        output_tensor = generator(image_tensor)

    output_image = transforms.ToPILImage()(output_tensor.squeeze().cpu())
    return output_image

def extract_pattern_with_color(image_array, contrast_threshold=0.6):

    image_float = image_array.astype(float) / 255.0


    gray_image = Image.fromarray(image_array).convert('L')
    gray_array = np.array(gray_image) / 255.0
    contrast = (gray_array - gray_array.min()) / (gray_array.max() - gray_array.min())
    mask = contrast > contrast_threshold
    mask = np.expand_dims(mask, axis=-1)
    mask = np.repeat(mask, 3, axis=-1)

    pattern = np.where(mask, image_float, 0)
    return pattern

def blend_pattern_with_base(base_image_path, pattern_image_path, alpha=0.5):

    base_image = load_image(base_image_path)
    pattern_image = load_image(pattern_image_path)

    transformed_base_image = transform_image(base_image, Gv2c)
    transformed_pattern_image = transform_image(pattern_image, Gc2v)

    base_image_array = np.array(transformed_base_image)
    pattern_image_array = np.array(transformed_pattern_image)


    if base_image_array.shape[:2] != pattern_image_array.shape[:2]:
        pattern_image = pattern_image.resize(base_image.size)
        pattern_image_array = np.array(pattern_image)


    pattern = extract_pattern_with_color(pattern_image_array)

    base_image_float = base_image_array.astype(float) / 255.0
    pattern_float = pattern.astype(float)

    blended_image = base_image_float * (1 - alpha) + pattern_float * alpha

    blended_image = np.clip(blended_image * 255, 0, 255)

    return blended_image


base_image_path = '/content/drive/MyDrive/contemporary_images/c2.png'
pattern_image_path = '/content/drive/MyDrive/vintage_images/v32.png'
output_path = '/content/drive/MyDrive/output2_final/nf2.png'


blended_with_pattern_image = blend_pattern_with_base(base_image_path, pattern_image_path, alpha=0.5)

save_image(blended_with_pattern_image, output_path)
# Out:
# <ipython-input-11-d451fb14ccb1>:32: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Gv2c.load_state_dict(torch.load('/content/drive/MyDrive/output/Gv2c.pth', map_location=device))
# <ipython-input-11-d451fb14ccb1>:33: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   Gc2v.load_state_dict(torch.load('/content/drive/MyDrive/output/Gc2v.pth', map_location=device))
